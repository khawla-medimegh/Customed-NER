# %%
#Import all required libraries
import json
import re
import spacy
import random
import time
import numpy as np
from spacy.util import minibatch, compounding
import sys
from spacy import displacy
from itertools import chain
import matplotlib.pyplot as plt 
from matplotlib.ticker import MaxNLocator

# %%
def calc_precision(pred, true):        
    precision = len([x for x in pred if x in true]) / (len(pred) + 1e-20) # true positives / total pred
    return precision

def calc_recall(pred, true):
    recall = len([x for x in true if x in pred]) / (len(true) + 1e-20)    # true positives / total test
    return recall

def calc_f1(precision, recall):
    f1 = 2 * ((precision * recall) / (precision + recall + 1e-20))
    return f1

# %%
# run the predictions on each sentence in the evaluation  dataset, and return the metrics
def evaluate(ner, data ):
    preds = [ner(x[0]) for x in data]

    precisions, recalls, f1s = [], [], []

    # iterate over predictions and test data and calculate precision, recall, and F1-score
    for pred, true in zip(preds, data):
        true = [x[2] for x in list(chain.from_iterable(true[1].values()))] # x[2] = annotation, true[1] = (start, end, annot)
        pred = [i.label_ for i in pred.ents] # i.label_ = annotation label, pred.ents = list of annotations
        precision = calc_precision(true, pred)
        precisions.append(precision)
        recall = calc_recall(true, pred)
        recalls.append(recall)
        f1s.append(calc_f1(precision, recall))

    #print("Precision: {} \nRecall: {} \nF1-score: {}".format(np.around(np.mean(precisions), 3),np.around(np.mean(recalls), 3),
    #                                                         np.around(np.mean(f1s), 3)))
    return {"textcat_p": np.mean(precisions), "textcat_r": np.mean(recalls), "textcat_f":np.mean(f1s)}

# %%
def train_spacy(train_data, labels, iterations, dropout = 0.5, display_freq = 1):
    ''' Train a spacy NER model, which can be queried against with test data
   
    train_data : training data in the format of (sentence, {entities: [(start, end, label)]})
    labels : a list of unique annotations
    iterations : number of training iterations
    dropout : dropout proportion for training
    display_freq : number of epochs between logging losses to console
    '''
    valid_f1scores=[]
    test_f1scores=[]
    #nlp = spacy.load("fr_core_news_md")
    nlp = spacy.blank('fr')
    if 'ner' not in nlp.pipe_names:
        ner = nlp.create_pipe('ner')
        nlp.add_pipe(ner)
    else:
        ner = nlp.get_pipe("ner")
   
    # Add entity labels to the NER pipeline
    for i in labels:
        ner.add_label(i)

    # Disable other pipelines in SpaCy to only train NER
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
    with nlp.disable_pipes(*other_pipes):
        #nlp.vocab.vectors.name = 'spacy_model' # without this, spaCy throws an "unnamed" error
        optimizer = nlp.begin_training()
        for itr in range(iterations):
            random.shuffle(train_data) # shuffle the training data before each iteration
            losses = {}
            batches = minibatch(train_data, size = compounding(16.0, 64.0, 1.5))
            for batch in batches:
                texts, annotations = zip(*batch)
                nlp.update(          
                    texts,
                    annotations,
                    drop = dropout,  
                    sgd = optimizer,
                    losses = losses)
            #if itr % display_freq == 0:
            #    print("Iteration {} Loss: {}".format(itr + 1, losses))
            scores = evaluate(nlp,VALID_DATA)
            valid_f1scores.append(scores["textcat_f"])
            print('=======================================')
            print('Interation = '+str(itr))
            print('Losses = '+str(losses))
            print('===============VALID DATA========================')
            
            print('F1-score = '+str(scores["textcat_f"]))
            print('Precision = '+str(scores["textcat_p"]))
            print('Recall = '+str(scores["textcat_r"]))
            scores = evaluate(nlp,TEST_DATA)
            test_f1scores.append(scores["textcat_f"])
            print('===============TEST DATA========================')
            print('F1-score = '+str(scores["textcat_f"]))
            print('Precision = '+str(scores["textcat_p"]))
            print('Recall = '+str(scores["textcat_r"]))
            print('=======================================')
            
    return nlp,valid_f1scores,test_f1scores

# %%
def trim_entity_spans(data: list) -> list:
    """Removes leading and trailing white spaces from entity spans.

    Args:
        data (list): The data to be cleaned in spaCy JSON format.

    Returns:
        list: The cleaned data.
    """
    invalid_span_tokens = re.compile(r'\s')

    cleaned_data = []
    i=0
    for text, annotations in data:
        entities = annotations['entities']
        valid_entities = []
        #i=i+1
        for start, end, label in entities:
            
            valid_start = start
            valid_end = end
            while valid_start < len(text) and invalid_span_tokens.match(
                    text[valid_start]):
                valid_start += 1
            while valid_end > 1 and invalid_span_tokens.match(
                    text[valid_end - 1]):
                valid_end -= 1
            valid_entities.append([valid_start, valid_end, label])
        cleaned_data.append([text, {'entities': valid_entities}])

    return cleaned_data

# %%
with open("C://Users//khawl//Desktop//final work//data//Validdata.json", encoding="utf8") as f:
    VALID_DATA = json.loads(f.read())
VALID_DATA = trim_entity_spans(VALID_DATA)
print(len(VALID_DATA))
with open("C://Users//khawl//Desktop//final work//data//Testdata.json", encoding="utf8") as f:
    TEST_DATA = json.loads(f.read())
TEST_DATA = trim_entity_spans(TEST_DATA)
print(len(TEST_DATA))
# Out:
# 889
# 390

# %%
with open("C://Users//khawl//Desktop//final work//data//Traindata.json", encoding="utf8") as f:
    TRAIN_DATA = json.loads(f.read())
TRAIN_DATA = trim_entity_spans(TRAIN_DATA)
print(len(TRAIN_DATA))
# Out:
# 499

# %%
LABELS = ["PERSON","ORG","SAL_NET","EMPLOI","DATE"]

# %%
# Train (and save) the NER model
ner,valid_f1scores,test_f1scores = train_spacy(TRAIN_DATA, LABELS,25)
# Out:
# =======================================
# Interation = 0
# Losses = {'ner': 45343.53946685791}
# ===============VALID DATA========================
# F1-score = 0.0
# Precision = 0.0
# Recall = 0.0
# ===============TEST DATA========================
# F1-score = 0.0
# Precision = 0.0
# Recall = 0.0
# =======================================
# =======================================
# Interation = 1
# Losses = {'ner': 5785.438940762542}
# ===============VALID DATA========================
# F1-score = 0.0
# Precision = 0.0
# Recall = 0.0
# ===============TEST DATA========================
# F1-score = 0.0
# Precision = 0.0
# Recall = 0.0
# =======================================
# =======================================
# Interation = 2
# Losses = {'ner': 6168.833797357976}
# ===============VALID DATA========================
# F1-score = 0.0
# Precision = 0.0
# Recall = 0.0
# ===============TEST DATA========================
# F1-score = 0.0
# Precision = 0.0
# Recall = 0.0
# =======================================
# =======================================
# Interation = 3
# Losses = {'ner': 5455.90491696354}
# ===============VALID DATA========================
# F1-score = 0.13434392129555234
# Precision = 0.0803283518131662
# Recall = 0.42744656917885265
# ===============TEST DATA========================
# F1-score = 0.1711843711843712
# Precision = 0.10159340659340658
# Recall = 0.5743589743589743
# =======================================
# =======================================
# Interation = 4
# Losses = {'ner': 5183.33241536282}
# ===============VALID DATA========================
# F1-score = 0.4404693419316591
# Precision = 0.3108305049531146
# Recall = 0.893888263967004
# ===============TEST DATA========================
# F1-score = 0.5317730702346087
# Precision = 0.3891575091575091
# Recall = 0.999145299145299
# =======================================
# =======================================
# Interation = 5
# Losses = {'ner': 5712.260558271781}
# ===============VALID DATA========================
# F1-score = 0.5743165033941187
# Precision = 0.4497559964095396
# Recall = 0.897225346831646
# ===============TEST DATA========================
# F1-score = 0.6861176288099364
# Precision = 0.5465689865689867
# Recall = 0.9973504273504274
# =======================================
# =======================================
# Interation = 6
# Losses = {'ner': 6877.325720321387}
# ===============VALID DATA========================
# F1-score = 0.7539719970941807
# Precision = 0.6514993661506598
# Recall = 0.9756226900208902
# ===============TEST DATA========================
# F1-score = 0.8357626435428633
# Precision = 0.7344993894993894
# Recall = 0.9944017094017094
# =======================================
# =======================================
# Interation = 7
# Losses = {'ner': 8528.50880742073}
# ===============VALID DATA========================
# F1-score = 0.7108421418601396
# Precision = 0.6106623441550325
# Recall = 0.9607424071991001
# ===============TEST DATA========================
# F1-score = 0.8062886970579277
# Precision = 0.7054761904761904
# Recall = 0.9973504273504274
# =======================================
# =======================================
# Interation = 8
# Losses = {'ner': 8869.708309958689}
# ===============VALID DATA========================
# F1-score = 0.859619354039029
# Precision = 0.786625738341149
# Recall = 0.9859053332619137
# ===============TEST DATA========================
# F1-score = 0.9012228282699747
# Precision = 0.8375457875457875
# Recall = 0.9960683760683762
# =======================================
# =======================================
# Interation = 9
# Losses = {'ner': 8191.405142276548}
# ===============VALID DATA========================
# F1-score = 0.8418237519560083
# Precision = 0.768823905128742
# Recall = 0.9856928598210938
# ===============TEST DATA========================
# F1-score = 0.9417728310656351
# Precision = 0.898913308913309
# Recall = 0.9964102564102565
# =======================================
# =======================================
# Interation = 10
# Losses = {'ner': 7583.4757388280705}
# ===============VALID DATA========================
# F1-score = 0.9037751862607402
# Precision = 0.8545810426294117
# Recall = 0.986028978520542
# ===============TEST DATA========================
# F1-score = 0.9700431817057127
# Precision = 0.9496825396825397
# Recall = 0.9960439560439562
# =======================================
# =======================================
# Interation = 11
# Losses = {'ner': 6225.993100859108}
# ===============VALID DATA========================
# F1-score = 0.9020714627301637
# Precision = 0.8532067420143911
# Recall = 0.9857865981038085
# ===============TEST DATA========================
# F1-score = 0.9647066323989401
# Precision = 0.9395421245421246
# Recall = 0.9963675213675215
# =======================================
# =======================================
# Interation = 12
# Losses = {'ner': 7659.606971127447}
# ===============VALID DATA========================
# F1-score = 0.8970035786357881
# Precision = 0.8453887663392725
# Recall = 0.9869864481225561
# ===============TEST DATA========================
# F1-score = 0.9519430996354074
# Precision = 0.9198595848595847
# Recall = 0.9965384615384615
# =======================================
# =======================================
# Interation = 13
# Losses = {'ner': 6921.254924438894}
# ===============VALID DATA========================
# F1-score = 0.9384435428084433
# Precision = 0.9093027738415816
# Recall = 0.9875122752513077
# ===============TEST DATA========================
# F1-score = 0.98532093538297
# Precision = 0.9773015873015873
# Recall = 0.9957203907203906
# =======================================
# =======================================
# Interation = 14
# Losses = {'ner': 5049.99755525589}
# ===============VALID DATA========================
# F1-score = 0.9481869199623641
# Precision = 0.9244057155193264
# Recall = 0.9862802863927723
# ===============TEST DATA========================
# F1-score = 0.9941724941724942
# Precision = 0.9930402930402931
# Recall = 0.9963003663003663
# =======================================
# =======================================
# Interation = 15
# Losses = {'ner': 4671.4767236709595}
# ===============VALID DATA========================
# F1-score = 0.9612597802966597
# Precision = 0.9431123463463171
# Recall = 0.9896883425286124
# ===============TEST DATA========================
# F1-score = 0.9906919291534677
# Precision = 0.9865934065934067
# Recall = 0.9963003663003663
# =======================================
# =======================================
# Interation = 16
# Losses = {'ner': 3998.931475616817}
# ===============VALID DATA========================
# F1-score = 0.9575807530328434
# Precision = 0.9401559788792635
# Recall = 0.9867288910314782
# ===============TEST DATA========================
# F1-score = 0.9966979459287152
# Precision = 0.9981684981684983
# Recall = 0.9958730158730159
# =======================================
# =======================================
# Interation = 17
# Losses = {'ner': 6428.782679065131}
# ===============VALID DATA========================
# F1-score = 0.9512780980266603
# Precision = 0.9274106564601502
# Recall = 0.9887875622690022
# ===============TEST DATA========================
# F1-score = 0.987455123224354
# Precision = 0.9808669108669109
# Recall = 0.996025641025641
# =======================================
# =======================================
# Interation = 18
# Losses = {'ner': 3385.0648174107773}
# ===============VALID DATA========================
# F1-score = 0.9706993557037268
# Precision = 0.959376019555997
# Recall = 0.9894441766207795
# ===============TEST DATA========================
# F1-score = 0.9964182256489948
# Precision = 0.9981684981684983
# Recall = 0.9954456654456656
# =======================================
# =======================================
# Interation = 19
# Losses = {'ner': 3135.7143164703157}
# ===============VALID DATA========================
# F1-score = 0.9646307874933818
# Precision = 0.9468391532227302
# Recall = 0.9908640884175193
# ===============TEST DATA========================
# F1-score = 0.9818841272687427
# Precision = 0.9713614163614164
# Recall = 0.9955311355311356
# =======================================
# =======================================
# Interation = 20
# Losses = {'ner': 3553.8973101244774}
# ===============VALID DATA========================
# F1-score = 0.9602945958102579
# Precision = 0.941373805547034
# Recall = 0.9901057697458148
# ===============TEST DATA========================
# F1-score = 0.9877733946964717
# Precision = 0.9819108669108669
# Recall = 0.9957020757020757
# =======================================
# =======================================
# Interation = 21
# Losses = {'ner': 2669.13013423307}
# ===============VALID DATA========================
# F1-score = 0.9725897152867151
# Precision = 0.9618850809233261
# Recall = 0.9894504258396273
# ===============TEST DATA========================
# F1-score = 0.9938003307234077
# Precision = 0.9929181929181929
# Recall = 0.9958730158730159
# =======================================
# =======================================
# Interation = 22
# Losses = {'ner': 2789.8366839687806}
# ===============VALID DATA========================
# F1-score = 0.9751761275663369
# Precision = 0.9663082293284768
# Recall = 0.9892616101558733
# ===============TEST DATA========================
# F1-score = 0.9909899786822866
# Precision = 0.9881746031746033
# Recall = 0.9952747252747253
# =======================================
# =======================================
# Interation = 23
# Losses = {'ner': 2383.7814803038054}
# ===============VALID DATA========================
# F1-score = 0.9752492868753744
# Precision = 0.9657404025795476
# Recall = 0.9901378399128681
# ===============TEST DATA========================
# F1-score = 0.9929792999023769
# Precision = 0.9915506715506714
# Recall = 0.9954456654456656
# =======================================
# =======================================
# Interation = 24
# Losses = {'ner': 2444.5955901892157}
# ===============VALID DATA========================
# F1-score = 0.9760108273310572
# Precision = 0.96645910332637
# Recall = 0.9908190047672611
# ===============TEST DATA========================
# F1-score = 0.9882092124399817
# Precision = 0.9831501831501832
# Recall = 0.9951465201465203
# =======================================

# %%
ner.to_disk("C://Users//khawl//Desktop//final work//spacy_trainedModel")

# %%
x=range(0,25)
 
ax = plt.figure().gca()
#...
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
ax.plot(valid_f1scores,label="Validation F1_score")
ax.plot(test_f1scores,label="Test F1_score")
ax.set_xlabel('Iterations')
ax.set_ylabel('F1 score')
ax.legend()
ax.set_title('F1 score vs Iterations for validation and test data')
# naming the x axis 
#ax.xlabel('Iteration') 
# naming the y axis 
#ax.ylabel('F1 score') 
# giving a title to my graph 
#
# show a legend on the plot 
#ax.legend() 
  
# function to show the plot
# Out:
# Text(0.5, 1.0, 'F1 score vs Iterations for validation and test data')

# %%
def load_model(model_path):
    ''' Loads a pre-trained model for prediction on new test sentences
   
    model_path : directory of model saved by spacy.to_disk
    '''
    #nlp = spacy.load("fr_core_news_md")
    nlp = spacy.blank('fr')
    if 'ner' not in nlp.pipe_names:
        ner = nlp.create_pipe('ner')
        nlp.add_pipe(ner)
    ner = nlp.from_disk(model_path)
    return ner

# %%
ner = load_model("C://Users//khawl//Desktop//final work//spacy_trainedModel")

# %%
with open("C://Users//khawl//Desktop//final work//data//Testdata.json", encoding="utf8") as f:
    TEST_DATA = json.loads(f.read())
TEST_DATA = trim_entity_spans(TEST_DATA)
print(len(TEST_DATA))
# Out:
# 390

# %%
test_sentences = [x[0] for x in TEST_DATA] # extract the sentences from [sentence, entity]
i=0
for x in test_sentences:
    i=i+1
    doc = ner(x)
    print("**************************************text n "+ str(i)+"**************************************\n")
    for ent in doc.ents:
        ch= str(ent.text) + " ===> " + str(ent.start_char) + " " + str(ent.end_char) + " " + str(ent.label_) + "\n" 
        print(ch)
    print("*************************************************************************************")
# Out:
# **************************************text n 1**************************************
#
# AVRIL 2017 ===> 31 41 DATE
#
# MINISTERE DE L'EDUCATION naTIOnaLE ===> 42 76 ORG
#
# NAOUEL BOCHRA ===> 140 153 PERSON
#
# PROFESSEUR ===> 169 179 EMPLOI
#
# 1161.314853 ===> 362 373 SAL_NET
#
# *************************************************************************************
# **************************************text n 2**************************************
#
# AVRIL 2017 ===> 31 41 DATE
#
# MINISTERE DE L'EDUCATION naTIOnaLE ===> 42 76 ORG
#
# NAMOUCHI FIRAS ===> 140 154 PERSON
#
# PROFESSEUR ===> 170 180 EMPLOI
#
# 1503.113867 ===> 363 374 SAL_NET
#
# *************************************************************************************
# **************************************text n 3**************************************
#
# AVRIL 2017 ===> 31 41 DATE
#
# MINISTERE DE LA DEFENSE naTIOnaLE ===> 42 75 ORG
#
# NASRI AICHA ===> 139 150 PERSON
#
# MILITAIRE ===> 166 175 EMPLOI
#
# 788.556133 ===> 358 368 SAL_NET
#
# *************************************************************************************
# **************************************text n 4**************************************
#
# AVRIL 2017 ===> 31 41 DATE
#
# MINISTERE DE LA DEFENSE naTIOnaLE ===> 42 75 ORG
#
# NEJI MALEK ===> 139 149 PERSON
#
# MILITAIRE ===> 165 174 EMPLOI
#
# 803.740933 ===> 357 367 SAL_NET
#
# *************************************************************************************
# **************************************text n 5**************************************
#
# AVRIL 2017 ===> 31 41 DATE
#
# MINISTERE DE LA DEFENSE naTIOnaLE ===> 42 75 ORG
#
# OMRI GHADA ===> 139 149 PERSON
#
# MILITAIRE ===> 165 174 EMPLOI
#
# 800.366533 ===> 357 367 SAL_NET
#
# *************************************************************************************
# **************************************text n 6**************************************
#
# AVRIL 2017 ===> 31 41 DATE
#
# MINISTERE DE LA DEFENSE naTIOnaLE ===> 42 75 ORG
#
# OBAYNA LINDA ===> 139 151 PERSON
#
# MILITAIRE ===> 167 176 EMPLOI
#
# 803.740933 ===> 359 369 SAL_NET
#
# *************************************************************************************
# **************************************text n 7**************************************
#
# AVRIL 2017 ===> 31 41 DATE
#
# MINISTERE DE L'EDUCATION naTIOnaLE ===> 42 76 ORG
#
# OUADA MOHAMED MOEMEN ===> 140 160 PERSON
#
# INSTITUTEUR ===> 176 187 EMPLOI
#
# 1270.633493 ===> 370 381 SAL_NET
#
# *************************************************************************************
# **************************************text n 8**************************************
#
# AVRIL 2017 ===> 31 41 DATE
#
# MINISTERE DE LA DEFENSE naTIOnaLE ===> 42 75 ORG
#
# OUALLANI ESSIA ===> 139 153 PERSON
#
# MILITAIRE ===> 169 178 EMPLOI
#
# 949.065093 ===> 361 371 SAL_NET
#
# *************************************************************************************
# **************************************text n 9**************************************
#
# AVRIL 2017 ===> 31 41 DATE
#
# MINISTERE DE LA DEFENSE naTIOnaLE ===> 42 75 ORG
#
# OUARGHI NADA ===> 139 151 PERSON
#
# MILITAIRE ===> 167 176 EMPLOI
#
# 793.167813 ===> 359 369 SAL_NET
#
# *************************************************************************************
# **************************************text n 10**************************************
#
# AVRIL 2017 ===> 31 41 DATE
#
# MINISTERE DE LA DEFENSE naTIOnaLE ===> 42 75 ORG
#
# OUERTANI SARRA ===> 139 153 PERSON
#
# MILITAIRE ===> 169 178 EMPLOI
#
# 793.167813 ===> 361 371 SAL_NET
#
# *************************************************************************************
# **************************************text n 11**************************************
#
# AVRIL 2017 ===> 31 41 DATE
#
# MINISTERE DE L'EDUCATION naTIOnaLE ===> 42 76 ORG
#
# RAHMANI EMNA ===> 140 152 PERSON
#
# PROFESSEUR ===> 168 178 EMPLOI
#
# 1287.348693 ===> 361 372 SAL_NET
#
# *************************************************************************************
# **************************************text n 12**************************************
#
# AVRIL 2017 ===> 31 41 DATE
#
# MINISTERE DE LA DEFENSE naTIOnaLE ===> 42 75 ORG
#
# OUESLATI MAHDI ===> 139 153 PERSON
#
# MILITAIRE ===> 169 178 EMPLOI
#
# 951.143964 ===> 361 371 SAL_NET
#
# *************************************************************************************
# **************************************text n 13**************************************
#
# AVRIL 2017 ===> 31 41 DATE
#
# MINISTERE DE L'EDUCATION naTIOnaLE ===> 42 76 ORG
#
# RHOUMA NADA ===> 140 151 PERSON
#
# PROFESSEUR ===> 167 177 EMPLOI
#
# 1287.348693 ===> 360 371 SAL_NET
#
# *************************************************************************************
# **************************************text n 14**************************************
#
# AVRIL 2017 ===> 31 41 DATE
#
# MINISTERE DE L'EDUCATION naTIOnaLE ===> 42 76 ORG
#
# REZGUI AMINE ===> 140 152 PERSON
#
# PROFESSEUR ===> 168 178 EMPLOI
#
# 1287.348693 ===> 361 372 SAL_NET
#
# *************************************************************************************
# **************************************text n 15**************************************
#
# AVRIL 2017 ===> 31 41 DATE
#
# MINISTERE DE L'EDUCATION naTIOnaLE ===> 42 76 ORG
#
# RIAHI AMIRA ===> 140 151 PERSON
#
# PROFESSEUR ===> 167 177 EMPLOI
#
# 1287.348693 ===> 360 371 SAL_NET
#
# *************************************************************************************
# **************************************text n 16**************************************
#
# AVRIL 2017 ===> 31 41 DATE
#
# MINISTERE DE L'EDUCATION naTIOnaLE ===> 42 76 ORG
#
# RIAHI MOHAMED ALI ===> 140 157 PERSON
#
# PROFESSEUR ===> 173 183 EMPLOI
#
# 1515.676373 ===> 366 377 SAL_NET
#
# *************************************************************************************
# **************************************text n 17**************************************
#
# AVRIL 2017 ===> 31 41 DATE
#
# MINISTERE DE LA DEFENSE naTIOnaLE ===> 42 75 ORG
#
# RIAHI MOHAMED KHALIL ===> 139 159 PERSON
#
# MILITAIRE ===> 175 184 EMPLOI
#
# 814.089093 ===> 367 377 SAL_NET
#
# *************************************************************************************
# **************************************text n 18**************************************
#
# AVRIL 2017 ===> 31 41 DATE
#
# MINISTERE DE L'EDUCATION naTIOnaLE ===> 42 76 ORG
#
# RIAHI MOHAMED KHALED ===> 140 160 PERSON
#
# PROFESSEUR ===> 176 186 EMPLOI
#
# 1600.982773 ===> 369 380 SAL_NET
#
# *************************************************************************************
# **************************************text n 19**************************************
#
# AVRIL 2017 ===> 31 41 DATE
#
# MINISTERE DE LA DEFENSE naTIOnaLE ===> 42 75 ORG
#
# RJAIBI ALI ===> 139 149 PERSON
#
# MILITAIRE ===> 165 174 EMPLOI
#
# 814.089093 ===> 357 367 SAL_NET
#
# *************************************************************************************
# **************************************text n 20**************************************
#
# AVRIL 2017 ===> 31 41 DATE
#
# MINISTERE DE L'EDUCATION naTIOnaLE ===> 42 76 ORG
#
# SAAFI WASSIM ===> 140 152 PERSON
#
# PROFESSEUR ===> 168 178 EMPLOI
#
# 1101.081813 ===> 361 372 SAL_NET
#
# *************************************************************************************
# **************************************text n 21**************************************
#
# AVRIL 2017 ===> 31 41 DATE
#
# MINISTERE DE LA DEFENSE naTIOnaLE ===> 42 75 ORG
#
# SAFI NOUR ===> 139 148 PERSON
#
# MILITAIRE ===> 164 173 EMPLOI
#
# 816.113733 ===> 356 366 SAL_NET
#
# *************************************************************************************
# **************************************text n 22**************************************
#
# AVRIL 2017 ===> 31 41 DATE
#
# MINISTERE DE LA DEFENSE naTIOnaLE ===> 42 75 ORG
#
# SAHLI RANIA ===> 139 150 PERSON
#
# MILITAIRE ===> 166 175 EMPLOI
#
# 1049.118533 ===> 358 369 SAL_NET
#
# *************************************************************************************
# **************************************text n 23**************************************
#
# AVRIL 2017 ===> 31 41 DATE
#
# MINISTERE DE LA DEFENSE naTIOnaLE ===> 42 75 ORG
#
# SAHLI SALMA ===> 139 150 PERSON
#
# MILITAIRE ===> 166 175 EMPLOI
#
# 814.089093 ===> 358 368 SAL_NET
#
# *************************************************************************************
# **************************************text n 24**************************************
#
# AVRIL 2017 ===> 31 41 DATE
#
# MINISTERE DE LA DEFENSE naTIOnaLE ===> 42 75 ORG
#
# SAIDI MOHAMED JIHED ===> 139 158 PERSON
#
# MILITAIRE ===> 174 183 EMPLOI
#
# 796.036053 ===> 366 376 SAL_NET
#
# *************************************************************************************
# **************************************text n 25**************************************
#
# MINISTERE DE L'EDUCATION naTIOnaLE ===> 0 34 ORG
#
# Juitlet 2017 ===> 91 103 DATE
#
# SAYHI MARAM ===> 128 139 PERSON
#
# INSTITUTEUR ===> 155 166 EMPLOI
#
# 1132.801173 ===> 322 333 SAL_NET
#
# *************************************************************************************
# **************************************text n 26**************************************
#
# MINISTERE DE LA DEFENSE naTIOnaLE ===> 0 33 ORG
#
# Juitlet 2017 ===> 90 102 DATE
#
# SASSI YASSMINE ===> 127 141 PERSON
#
# MILITAIRE ===> 157 166 EMPLOI
#
# 1123.284693 ===> 322 333 SAL_NET
#
# *************************************************************************************
# **************************************text n 27**************************************
#
# MINISTERE DE L'EDUCATION naTIOnaLE ===> 0 34 ORG
#
# Juitlet 2017 ===> 91 103 DATE
#
# SELLAMI MOHAMED AMINE ===> 128 149 PERSON
#
# INSTITUTEUR ===> 165 176 EMPLOI
#
# 1098.764053 ===> 332 343 SAL_NET
#
# *************************************************************************************
# **************************************text n 28**************************************
#
# MINISTERE DE L'EDUCATION naTIOnaLE ===> 0 34 ORG
#
# Juitlet 2017 ===> 91 103 DATE
#
# SELMI HAZEM ===> 128 139 PERSON
#
# INSTITUTEUR ===> 155 166 EMPLOI
#
# 758.154 ===> 342 349 SAL_NET
#
# *************************************************************************************
# **************************************text n 29**************************************
#
# MINISTERE DE L'EDUCATION naTIOnaLE ===> 0 34 ORG
#
# Juitlet 2017 ===> 91 103 DATE
#
# SLOUMA ONS ===> 128 138 PERSON
#
# INSTITUTEUR ===> 154 165 EMPLOI
#
# 1157.141173 ===> 321 332 SAL_NET
#
# *************************************************************************************
# **************************************text n 30**************************************
#
# MINISTERE DE L'EDUCATION naTIOnaLE ===> 0 34 ORG
#
# Juitlet 2017 ===> 91 103 DATE
#
# SGHAIER ZAINEB ===> 128 142 PERSON
#
# INSTITUTEUR ===> 158 169 EMPLOI
#
# 758.154 ===> 345 352 SAL_NET
#
# *************************************************************************************
# **************************************text n 31**************************************
#
# MINISTERE DE L'EDUCATION naTIOnaLE ===> 0 34 ORG
#
# Juitlet 2017 ===> 91 103 DATE
#
# SOUSSI YASSINE ===> 128 142 PERSON
#
# INSTITUTEUR ===> 158 169 EMPLOI
#
# 1400.813307 ===> 325 336 SAL_NET
#
# *************************************************************************************
# **************************************text n 32**************************************
#
# MINISTERE DE LA DEFENSE naTIOnaLE ===> 0 33 ORG
#
# Juitlet 2017 ===> 90 102 DATE
#
# TAKALI ARIJ ===> 127 138 PERSON
#
# MILITAIRE ===> 154 163 EMPLOI
#
# 933.205413 ===> 319 329 SAL_NET
#
# *************************************************************************************
# **************************************text n 33**************************************
#
# MINISTERE DE L'EDUCATION naTIOnaLE ===> 0 34 ORG
#
# Juitlet 2017 ===> 91 103 DATE
#
# TALBI GHADA ===> 128 139 PERSON
#
# PROFESSEUR ===> 155 165 EMPLOI
#
# 1368.151973 ===> 321 332 SAL_NET
#
# *************************************************************************************
# **************************************text n 34**************************************
#
# MINISTERE DE L'EDUCATION naTIOnaLE ===> 0 34 ORG
#
# Juitlet 2017 ===> 91 103 DATE
#
# TARHOUNI MOHAMED CHADI ===> 128 150 PERSON
#
# INSTITUTEUR ===> 166 177 EMPLOI
#
# 654.761173 ===> 333 343 SAL_NET
#
# *************************************************************************************
# **************************************text n 35**************************************
#
# MINISTERE DE L'EDUCATION naTIOnaLE ===> 0 34 ORG
#
# Juitlet 2017 ===> 91 103 DATE
#
# SMAALI CAMILIA ===> 128 142 PERSON
#
# INSTITUTEUR ===> 158 169 EMPLOI
#
# 1132.801173 ===> 325 336 SAL_NET
#
# *************************************************************************************
# **************************************text n 36**************************************
#
# MINISTERE DE L'EDUCATION naTIOnaLE ===> 0 34 ORG
#
# Juitlet 2017 ===> 91 103 DATE
#
# TAYECH ICHRAK ===> 128 141 PERSON
#
# PROFESSEUR ===> 157 167 EMPLOI
#
# 1117.447653 ===> 323 334 SAL_NET
#
# *************************************************************************************
# **************************************text n 37**************************************
#
# SONEDE ===> 0 6 ORG
#
# Juitlet 2017 ===> 63 75 DATE
#
# THEMRI ONS ===> 100 110 PERSON
#
# INGENIEUR ===> 126 135 EMPLOI
#
# 1998.385537 ===> 291 302 SAL_NET
#
# *************************************************************************************
# **************************************text n 38**************************************
#
# MINISTERE DE L'EDUCATION naTIOnaLE ===> 0 34 ORG
#
# Juitlet 2017 ===> 91 103 DATE
#
# THABET AMAL ===> 128 139 PERSON
#
# PROFESSEUR ===> 155 165 EMPLOI
#
# 1191.290773 ===> 321 332 SAL_NET
#
# *************************************************************************************
# **************************************text n 39**************************************
#
# OnaS OFFICE naT DE L'ASSAINISSEMENT ===> 0 35 ORG
#
# Juitlet 2017 ===> 92 104 DATE
#
# TLIBA CHAIMA ===> 129 141 PERSON
#
# INGENIEUR ===> 157 166 EMPLOI
#
# 3211.53216 ===> 322 332 SAL_NET
#
# *************************************************************************************
# **************************************text n 40**************************************
#
# MINISTERE DE L'EDUCATION naTIOnaLE ===> 0 34 ORG
#
# Juitlet 2017 ===> 91 103 DATE
#
# TOUMIA MOHAMED AZIZ ===> 128 147 PERSON
#
# INSTITUTEUR ===> 163 174 EMPLOI
#
# 898.774613 ===> 330 340 SAL_NET
#
# *************************************************************************************
# **************************************text n 41**************************************
#
# EMPLOYEUR eTABLIT ===> 0 17 ORG
#
# Juitlet 2017 ===> 87 99 DATE
#
# TOMBARI EYA ===> 124 135 PERSON
#
# INGENIEUR ===> 151 160 EMPLOI
#
# 8995.853688 ===> 316 327 SAL_NET
#
# *************************************************************************************
# **************************************text n 42**************************************
#
# GROUPE CHIMIQUE TUNISIEN ===> 0 24 ORG
#
# Juitlet 2017 ===> 81 93 DATE
#
# TRABELSI SIRYNE ===> 118 133 PERSON
#
# TECHNICIEN ===> 149 159 EMPLOI
#
# 1092.746608 ===> 315 326 SAL_NET
#
# *************************************************************************************
# **************************************text n 43**************************************
#
# MINISTERE DE L'EDUCATION naTIOnaLE ===> 0 34 ORG
#
# Juitlet 2017 ===> 91 103 DATE
#
# TRIKI SAWSEN ===> 128 140 PERSON
#
# INSTITUTEUR ===> 156 167 EMPLOI
#
# 686.986693 ===> 323 333 SAL_NET
#
# *************************************************************************************
# **************************************text n 44**************************************
#
# MINISTERE DE L'EDUCATION naTIOnaLE ===> 0 34 ORG
#
# Juitlet 2017 ===> 91 103 DATE
#
# TURKI MOHAMED AZIZ ===> 128 146 PERSON
#
# INSTITUTEUR ===> 162 173 EMPLOI
#
# 968.636613 ===> 329 339 SAL_NET
#
# *************************************************************************************
# **************************************text n 45**************************************
#
# Juitlet 2017 ===> 86 98 DATE
#
# TURKI YASSINE ===> 123 136 PERSON
#
# TECHNICIEN ===> 152 162 EMPLOI
#
# 491.780499 ===> 318 328 SAL_NET
#
# *************************************************************************************
# **************************************text n 46**************************************
#
# MINISTERE DE LA SANTE ===> 0 21 ORG
#
# Juitlet 2017 ===> 78 90 DATE
#
# ZAGROUBA RANIA ===> 115 129 PERSON
#
# TECHNICIEN ===> 145 155 EMPLOI
#
# 1019.252613 ===> 311 322 SAL_NET
#
# *************************************************************************************
# **************************************text n 47**************************************
#
# GROUPE CHIMIQUE TUNISIEN ===> 0 24 ORG
#
# Juitlet 2017 ===> 81 93 DATE
#
# ZAIBI DHEKRA ===> 118 130 PERSON
#
# TECHNICIEN ===> 146 156 EMPLOI
#
# 1092.746608 ===> 312 323 SAL_NET
#
# *************************************************************************************
# **************************************text n 48**************************************
#
# Juitlet 2017 ===> 85 97 DATE
#
# ZNEIDI GHASSENE ===> 122 137 PERSON
#
# TECHNICIEN ===> 153 163 EMPLOI
#
# 1248.205653 ===> 319 330 SAL_NET
#
# *************************************************************************************
# **************************************text n 49**************************************
#
# TOUS HOPITAUX ===> 0 13 ORG
#
# Juitlet 2017 ===> 93 105 DATE
#
# ZOMITA ABDELLHAK ===> 130 146 PERSON
#
# TECHNICIEN ===> 162 172 EMPLOI
#
# 1034.443037 ===> 328 339 SAL_NET
#
# *************************************************************************************
# **************************************text n 50**************************************
#
# MINISTERE DE LA SANTE ===> 0 21 ORG
#
# Juitlet 2017 ===> 78 90 DATE
#
# ZAIEM ANIS ===> 115 125 PERSON
#
# TECHNICIEN ===> 141 151 EMPLOI
#
# 1019.252613 ===> 307 318 SAL_NET
#
# *************************************************************************************
# **************************************text n 51**************************************
#
# MINISTERE DE L'AGRICULTURE ===> 0 26 ORG
#
# Juitlet 2017 ===> 83 95 DATE
#
# ZOUAGHI FERIEL ===> 120 134 PERSON
#
# TECHNICIEN ===> 150 160 EMPLOI
#
# 1560.031893 ===> 316 327 SAL_NET
#
# *************************************************************************************
# **************************************text n 52**************************************
#
# MINISTERE DE L'AGRICULTURE ===> 0 26 ORG
#
# Juitlet 2017 ===> 83 95 DATE
#
# ABDELKADER MINYAR ===> 120 137 PERSON
#
# TECHNICIEN ===> 153 163 EMPLOI
#
# 1560.031893 ===> 319 330 SAL_NET
#
# *************************************************************************************
# **************************************text n 53**************************************
#
# Juitlet 2017 ===> 85 97 DATE
#
# ABDESLEM ZAHER ===> 122 136 PERSON
#
# TECHNICIEN ===> 152 162 EMPLOI
#
# 1248.205653 ===> 318 329 SAL_NET
#
# *************************************************************************************
# **************************************text n 54**************************************
#
# STE CFPTS SARL ===> 0 14 ORG
#
# Juitlet 2017 ===> 71 83 DATE
#
# ALOUI MAHDI ===> 108 119 PERSON
#
# TECHNICIEN ===> 135 145 EMPLOI
#
# 652.768597 ===> 301 311 SAL_NET
#
# *************************************************************************************
# **************************************text n 55**************************************
#
# TUNISIE              TELECOM ===> 0 28 ORG
#
# Juitlet 2017 ===> 85 97 DATE
#
# AYARI HEJER ===> 122 133 PERSON
#
# INGENIEUR ===> 149 158 EMPLOI
#
# 2201.223977 ===> 314 325 SAL_NET
#
# *************************************************************************************
# **************************************text n 56**************************************
#
# MINISTERE DE LA SANTE ===> 0 21 ORG
#
# Juitlet 2017 ===> 78 90 DATE
#
# ZOUZIA GHOFRANE ===> 115 130 PERSON
#
# TECHNICIEN ===> 146 156 EMPLOI
#
# 944.959573 ===> 312 322 SAL_NET
#
# *************************************************************************************
# **************************************text n 57**************************************
#
# TUNISIE              TELECOM ===> 0 28 ORG
#
# Juitlet 2017 ===> 85 97 DATE
#
# BATNINI IKRAM ===> 122 135 PERSON
#
# INGENIEUR ===> 151 160 EMPLOI
#
# 2201.223977 ===> 316 327 SAL_NET
#
# *************************************************************************************
# **************************************text n 58**************************************
#
# LABO D'AnaLYSE MEDIC DHOUHA DEROUICH ===> 0 36 ORG
#
# Juitlet 2017 ===> 93 105 DATE
#
# BATTIKH AYA ===> 130 141 PERSON
#
# TECHNICIEN ===> 157 167 EMPLOI
#
# 609.248016 ===> 323 333 SAL_NET
#
# *************************************************************************************
# **************************************text n 59**************************************
#
# LABO D'AnaLYSE MEDIC DHOUHA DEROUICH ===> 0 36 ORG
#
# Juitlet 2017 ===> 93 105 DATE
#
# BEN AMOR HAITHEM ===> 130 146 PERSON
#
# TECHNICIEN ===> 162 172 EMPLOI
#
# 609.248016 ===> 328 338 SAL_NET
#
# *************************************************************************************
# **************************************text n 60**************************************
#
# LABO D'AnaLYSE MEDIC DHOUHA DEROUICH ===> 0 36 ORG
#
# Juitlet 2017 ===> 93 105 DATE
#
# BEN HAMOUDA MELEK ===> 130 147 PERSON
#
# TECHNICIEN ===> 163 173 EMPLOI
#
# 609.248016 ===> 329 339 SAL_NET
#
# *************************************************************************************
# **************************************text n 61**************************************
#
# GROUPE CHIMIQUE TUNISIEN ===> 0 24 ORG
#
# Juitlet 2017 ===> 81 93 DATE
#
# BEN MUSTAPHA LEILA ===> 118 136 PERSON
#
# TECHNICIEN ===> 152 162 EMPLOI
#
# 1092.746608 ===> 318 329 SAL_NET
#
# *************************************************************************************
# **************************************text n 62**************************************
#
# TUNISIE              TELECOM ===> 0 28 ORG
#
# Juitlet 2017 ===> 85 97 DATE
#
# AZZOUZ WAEL ===> 122 133 PERSON
#
# INGENIEUR ===> 149 158 EMPLOI
#
# 2201.223977 ===> 314 325 SAL_NET
#
# *************************************************************************************
# **************************************text n 63**************************************
#
# MEDIA DIFFUSION CANON ===> 0 21 ORG
#
# Juitlet 2017 ===> 78 90 DATE
#
# BEN RHOUMA KHALIL ALLAH ===> 115 138 PERSON
#
# TECHNICIEN ===> 154 164 EMPLOI
#
# 666.093768 ===> 320 330 SAL_NET
#
# *************************************************************************************
# **************************************text n 64**************************************
#
# SONEDE ===> 0 6 ORG
#
# Juitlet 2017 ===> 63 75 DATE
#
# BEN SAAD MOEZ ===> 100 113 PERSON
#
# INGENIEUR ===> 129 138 EMPLOI
#
# 1976.542805 ===> 294 305 SAL_NET
#
# *************************************************************************************
# **************************************text n 65**************************************
#
# MEDIA DIFFUSION CANON ===> 0 21 ORG
#
# Juitlet 2017 ===> 78 90 DATE
#
# BEN NACEUR HAMZA ===> 115 131 PERSON
#
# TECHNICIEN ===> 147 157 EMPLOI
#
# 666.093768 ===> 313 323 SAL_NET
#
# *************************************************************************************
# **************************************text n 66**************************************
#
# AVENIR POUR L'ENERIGIE PHOTOVOLTAIQU ===> 0 36 ORG
#
# Juitlet 2017 ===> 93 105 DATE
#
# BEN TURKIA SAIDA ===> 130 146 PERSON
#
# INGENIEUR ===> 162 171 EMPLOI
#
# 1215.62591 ===> 327 337 SAL_NET
#
# *************************************************************************************
# **************************************text n 67**************************************
#
# MINISTERE DE LA FORMATION PROLLE EMP ===> 0 36 ORG
#
# Juitlet 2017 ===> 93 105 DATE
#
# BOUCHUICHA FIRAS ===> 130 146 PERSON
#
# PROFESSION INTERMEDIA. ===> 162 184 EMPLOI
#
# 1389.059147 ===> 340 351 SAL_NET
#
# *************************************************************************************
# **************************************text n 68**************************************
#
# ETABLISSEMENT MHIRSI DES ABRASIF ===> 0 32 ORG
#
# Juitlet 2017 ===> 89 101 DATE
#
# BEN YOUSSEF CYRINE ===> 126 144 PERSON
#
# PROFESSION INTERMEDIA. ===> 160 182 EMPLOI
#
# 836.350994 ===> 338 348 SAL_NET
#
# *************************************************************************************
# **************************************text n 69**************************************
#
# OFFICE DES TERRES DOMANIALES ===> 0 28 ORG
#
# Juitlet 2017 ===> 91 103 DATE
#
# CHABANE MOHAMMED YASSINE ===> 128 152 PERSON
#
# INGENIEUR ===> 168 177 EMPLOI
#
# 1126.333573 ===> 333 344 SAL_NET
#
# *************************************************************************************
# **************************************text n 70**************************************
#
# CENTRALE LAITIERE DE MAHDIA ===> 0 27 ORG
#
# Juitlet 2017 ===> 84 96 DATE
#
# BOUJLIDA RIHEM ===> 121 135 PERSON
#
# INGENIEUR ===> 151 160 EMPLOI
#
# 2887.677333 ===> 316 327 SAL_NET
#
# *************************************************************************************
# **************************************text n 71**************************************
#
# ETABLISSEMENT MHIRSI DES ABRASIF ===> 0 32 ORG
#
# Juitlet 2017 ===> 89 101 DATE
#
# CHAGWEY DHIA EDDINE ===> 126 145 PERSON
#
# PROFESSION INTERMEDIA. ===> 161 183 EMPLOI
#
# 836.350994 ===> 339 349 SAL_NET
#
# *************************************************************************************
# **************************************text n 72**************************************
#
# ETABLISSEMENT MHIRSI DES ABRASIF ===> 0 32 ORG
#
# Juitlet 2017 ===> 89 101 DATE
#
# DACHRAOUI SUZANE ===> 126 142 PERSON
#
# PROFESSION INTERMEDIA. ===> 158 180 EMPLOI
#
# 836.350994 ===> 336 346 SAL_NET
#
# *************************************************************************************
# **************************************text n 73**************************************
#
# STE MUTUELLE CENTRALE DE SEMENCES ===> 0 33 ORG
#
# Juitlet 2017 ===> 90 102 DATE
#
# CHOUIKHA HAMIDA ===> 127 142 PERSON
#
# INGENIEUR ===> 158 167 EMPLOI
#
# 1448.981929 ===> 323 334 SAL_NET
#
# *************************************************************************************
# **************************************text n 74**************************************
#
# STE PLASTICUM TUNISIE ===> 0 21 ORG
#
# Juitlet 2017 ===> 78 90 DATE
#
# DAGHNOUJ MAHDI ===> 115 129 PERSON
#
# PROFESSION INTERMEDIA. ===> 145 167 EMPLOI
#
# 587.181783 ===> 323 333 SAL_NET
#
# *************************************************************************************
# **************************************text n 75**************************************
#
# MARQUARDT AUTOMOTIVE TUNISIE ===> 0 28 ORG
#
# Juitlet 2017 ===> 91 103 DATE
#
# DRIDI ZINA ===> 128 138 PERSON
#
# INGENIEUR ===> 154 163 EMPLOI
#
# 1796.392253 ===> 319 330 SAL_NET
#
# *************************************************************************************
# **************************************text n 76**************************************
#
# TUNISIE AUTOROUTES .SA ===> 0 22 ORG
#
# Juitlet 2017 ===> 79 91 DATE
#
# DURMUS AHMED ILHAN ===> 116 134 PERSON
#
# AGRICULT. EXP MOY ===> 150 167 EMPLOI
#
# 888.436264 ===> 326 336 SAL_NET
#
# *************************************************************************************
# **************************************text n 77**************************************
#
# MINISTERE DE L'EDUCATION naTIOnaLE ===> 0 34 ORG
#
# Juitlet 2017 ===> 91 103 DATE
#
# DALENSI MOLKA ===> 128 141 PERSON
#
# INGENIEUR ===> 157 166 EMPLOI
#
# 2133.15424 ===> 322 332 SAL_NET
#
# *************************************************************************************
# **************************************text n 78**************************************
#
# AGET ===> 0 4 ORG
#
# Juitlet 2017 ===> 61 73 DATE
#
# EL AYED MOHAMED KHALIL ===> 98 120 PERSON
#
# PROFESSION INTERMEDIA. ===> 136 158 EMPLOI
#
# 777.040993 ===> 314 324 SAL_NET
#
# *************************************************************************************
# **************************************text n 79**************************************
#
# MINISTERE DE LA FORMATION PROLLE EMP ===> 0 36 ORG
#
# Juitlet 2017 ===> 93 105 DATE
#
# EL BENNA INES ===> 130 143 PERSON
#
# PROFESSION INTERMEDIA. ===> 159 181 EMPLOI
#
# 1392.309147 ===> 337 348 SAL_NET
#
# *************************************************************************************
# **************************************text n 80**************************************
#
# OnaS OFFICE naT DE L'ASSAINISSEMENT ===> 0 35 ORG
#
# Juitlet 2017 ===> 92 104 DATE
#
# EL ACHKHAM ZAINEB ===> 129 146 PERSON
#
# PROFESSION INTERMEDIA. ===> 162 184 EMPLOI
#
# 821.344053 ===> 340 350 SAL_NET
#
# *************************************************************************************
# **************************************text n 81**************************************
#
# STE HAna TRABELSI ===> 0 17 ORG
#
# Juitlet 2017 ===> 74 86 DATE
#
# EL GATT MOHAMED ===> 111 126 PERSON
#
# PROFESSION INTERMEDIA. ===> 142 164 EMPLOI
#
# 27432.488 ===> 320 329 SAL_NET
#
# *************************************************************************************
# **************************************text n 82**************************************
#
# STE TRADE PLUS ===> 0 14 ORG
#
# Juitlet 2017 ===> 71 83 DATE
#
# EL GATT HAMZA ===> 108 121 PERSON
#
# PROFESSION INTERMEDIA. ===> 137 159 EMPLOI
#
# 528.937561 ===> 315 325 SAL_NET
#
# *************************************************************************************
# **************************************text n 83**************************************
#
# MUNICIPALITE DE TUNIS ===> 0 21 ORG
#
# Juitlet 2017 ===> 78 90 DATE
#
# FARAH AHMED ===> 115 126 PERSON
#
# PROFESSION INTERMEDIA. ===> 142 164 EMPLOI
#
# 709.527013 ===> 320 330 SAL_NET
#
# *************************************************************************************
# **************************************text n 84**************************************
#
# Juitlet 2017 ===> 93 105 DATE
#
# GASSA ZEINEB ===> 130 142 PERSON
#
# PROFESSION INTERMEDIA. ===> 158 180 EMPLOI
#
# 1388.609227 ===> 336 347 SAL_NET
#
# *************************************************************************************
# **************************************text n 85**************************************
#
# TRANSTU ===> 0 7 ORG
#
# Juitlet 2017 ===> 64 76 DATE
#
# GASMI ANGHAM ===> 101 113 PERSON
#
# PROFESSION INTERMEDIA. ===> 129 151 EMPLOI
#
# 1302.702213 ===> 307 318 SAL_NET
#
# *************************************************************************************
# **************************************text n 86**************************************
#
# STE HAna TRABELSI ===> 0 17 ORG
#
# Juitlet 2017 ===> 74 86 DATE
#
# GHARBI SEDDIK ===> 111 124 PERSON
#
# PROFESSION INTERMEDIA. ===> 140 162 EMPLOI
#
# 1686.657877 ===> 318 329 SAL_NET
#
# *************************************************************************************
# **************************************text n 87**************************************
#
# MINISTERE DE LA FORMATION PROLLE EMP ===> 0 36 ORG
#
# Juitlet 2017 ===> 93 105 DATE
#
# HAMMAMI AHMED ===> 130 143 PERSON
#
# PROFESSION INTERMEDIA. ===> 159 181 EMPLOI
#
# 1392.309147 ===> 337 348 SAL_NET
#
# *************************************************************************************
# **************************************text n 88**************************************
#
# MOI-MÊME ===> 0 8 ORG
#
# Juitlet 2017 ===> 65 77 DATE
#
# HAMILA MOHAMED RIDHA ===> 102 122 PERSON
#
# PROFESSION INTERMEDIA. ===> 138 160 EMPLOI
#
# 3125.556667 ===> 316 327 SAL_NET
#
# *************************************************************************************
# **************************************text n 89**************************************
#
# Juitlet 2017 ===> 85 97 DATE
#
# HAMMAMI MOHAMED MAHDI ===> 122 143 PERSON
#
# AGRICULT. EXP MOY ===> 159 176 EMPLOI
#
# 952.916541 ===> 335 345 SAL_NET
#
# *************************************************************************************
# **************************************text n 90**************************************
#
# STE TRANSPORT DU SAHEL ===> 0 22 ORG
#
# Juitlet 2017 ===> 79 91 DATE
#
# JANIH RIM ===> 116 125 PERSON
#
# PROFESSION INTERMEDIA. ===> 141 163 EMPLOI
#
# 1085.421067 ===> 319 330 SAL_NET
#
# *************************************************************************************
# **************************************text n 91**************************************
#
# Ministere de la jeunesse et des spor ===> 0 36 ORG
#
# Juitlet 2017 ===> 93 105 DATE
#
# JAOUADI HAYTHEM ===> 130 145 PERSON
#
# PROFESSION INTERMEDIA. ===> 161 183 EMPLOI
#
# 1261.592293 ===> 339 350 SAL_NET
#
# *************************************************************************************
# **************************************text n 92**************************************
#
# Juitlet 2017 ===> 85 97 DATE
#
# HOSSNI MERIAM ===> 122 135 PERSON
#
# AGRICULT. EXP MOY ===> 151 168 EMPLOI
#
# 952.916541 ===> 327 337 SAL_NET
#
# *************************************************************************************
# **************************************text n 93**************************************
#
# ETABLISSEMENT MHIRSI DES ABRASIF ===> 0 32 ORG
#
# Juitlet 2017 ===> 89 101 DATE
#
# KACHROUDI ZIED ===> 126 140 PERSON
#
# PROFESSION INTERMEDIA. ===> 156 178 EMPLOI
#
# 861.929993 ===> 334 344 SAL_NET
#
# *************************************************************************************
# **************************************text n 94**************************************
#
# NOUVELAIR TUNISIE ===> 0 17 ORG
#
# Juitlet 2017 ===> 74 86 DATE
#
# JRID YOUSSEF ===> 111 123 PERSON
#
# PROFESSION INTERMEDIA. ===> 139 161 EMPLOI
#
# 1165.158413 ===> 317 328 SAL_NET
#
# *************************************************************************************
# **************************************text n 95**************************************
#
# STE STAR ===> 0 8 ORG
#
# Juitlet 2017 ===> 72 84 DATE
#
# KHLIFI SIRINE ===> 109 122 PERSON
#
# PROFESSION INTERMEDIA. ===> 138 160 EMPLOI
#
# 410.73345 ===> 316 325 SAL_NET
#
# *************************************************************************************
# **************************************text n 96**************************************
#
# STE ADLY CHIMIC ===> 0 15 ORG
#
# Juitlet 2017 ===> 72 84 DATE
#
# KHMIRA MANAR ===> 109 121 PERSON
#
# CADRE ADMIN. SUP ===> 137 153 EMPLOI
#
# 11796.0 ===> 309 316 SAL_NET
#
# *************************************************************************************
# **************************************text n 97**************************************
#
# MINISTERE DE L'ENS SUP ===> 0 22 ORG
#
# Juitlet 2017 ===> 79 91 DATE
#
# KHRAIFI AYA ===> 116 127 PERSON
#
# CADRE ADMIN. SUP ===> 143 159 EMPLOI
#
# 1806.620533 ===> 315 326 SAL_NET
#
# *************************************************************************************
# **************************************text n 98**************************************
#
# MINISTERE DE LA JUSTICE ===> 0 23 ORG
#
# Juitlet 2017 ===> 80 92 DATE
#
# LABIDI MARAM ===> 117 129 PERSON
#
# CADRE ADMIN. SUP ===> 145 161 EMPLOI
#
# 1438.212907 ===> 317 328 SAL_NET
#
# *************************************************************************************
# **************************************text n 99**************************************
#
# SOFRECOM ===> 0 8 ORG
#
# Juitlet 2017 ===> 65 77 DATE
#
# LABIDI WISSAL ===> 102 115 PERSON
#
# CADRE ADMIN. SUP ===> 131 147 EMPLOI
#
# 5109.650294 ===> 303 314 SAL_NET
#
# *************************************************************************************
# **************************************text n 100**************************************
#
# TUNISIE LEASING ===> 0 15 ORG
#
# Juitlet 2017 ===> 72 84 DATE
#
# MAAOUIA MOHAMED MALEK ===> 109 130 PERSON
#
# CADRE ADMIN. SUP ===> 146 162 EMPLOI
#
# 2763.965919 ===> 318 329 SAL_NET
#
# *************************************************************************************
# **************************************text n 101**************************************
#
# TUNISIE LEASING ===> 0 15 ORG
#
# Juitlet 2017 ===> 72 84 DATE
#
# MAAREF IMEN ===> 109 120 PERSON
#
# CADRE ADMIN. SUP ===> 136 152 EMPLOI
#
# 2763.965919 ===> 308 319 SAL_NET
#
# *************************************************************************************
# **************************************text n 102**************************************
#
# MINISTERE DU COMMERCE ===> 0 21 ORG
#
# Juitlet 2017 ===> 91 103 DATE
#
# MAAYOUFI MALEK ===> 128 142 PERSON
#
# CADRE ADMIN. SUP ===> 158 174 EMPLOI
#
# 1595.239253 ===> 330 341 SAL_NET
#
# *************************************************************************************
# **************************************text n 103**************************************
#
# CIMPRESS ===> 0 8 ORG
#
# Juitlet 2017 ===> 65 77 DATE
#
# MAHJOUB FERIEL ===> 102 116 PERSON
#
# CADRE ADMIN. SUP ===> 132 148 EMPLOI
#
# 757.69376 ===> 304 313 SAL_NET
#
# *************************************************************************************
# **************************************text n 104**************************************
#
# EMPLOYEUR eTABLIT ===> 0 17 ORG
#
# Juitlet 2017 ===> 87 99 DATE
#
# MASMOUDI FARAH ===> 124 138 PERSON
#
# PROFESSION INTERMEDIA. ===> 154 176 EMPLOI
#
# 4664.651672 ===> 332 343 SAL_NET
#
# *************************************************************************************
# **************************************text n 105**************************************
#
# DACHSER TUNISIA ===> 0 15 ORG
#
# Juitlet 2017 ===> 72 84 DATE
#
# MBARKI SOUAD ===> 109 121 PERSON
#
# CADRE ADMIN. SUP ===> 137 153 EMPLOI
#
# 1689.357289 ===> 309 320 SAL_NET
#
# *************************************************************************************
# **************************************text n 106**************************************
#
# STE FEZZANI TRANSPORT DE MARCHANDISE ===> 0 36 ORG
#
# Juitlet 2017 ===> 93 105 DATE
#
# KHEMISSI ALAA ===> 130 143 PERSON
#
# PROFESSION INTERMEDIA. ===> 159 181 EMPLOI
#
# 1466.063658 ===> 337 348 SAL_NET
#
# *************************************************************************************
# **************************************text n 107**************************************
#
# OnaS OFFICE naT DE L'ASSAINISSEMENT ===> 0 35 ORG
#
# Juitlet 2017 ===> 92 104 DATE
#
# MEJRI ABDELAZIZ ===> 129 144 PERSON
#
# CADRE ADMIN. SUP ===> 160 176 EMPLOI
#
# 7047.4359 ===> 332 341 SAL_NET
#
# *************************************************************************************
# **************************************text n 108**************************************
#
# OFFICE naTIOnaL DES POSTES ===> 0 26 ORG
#
# Juitlet 2017 ===> 83 95 DATE
#
# MELKI AMAL ===> 120 130 PERSON
#
# PROFESSION INTERMEDIA. ===> 146 168 EMPLOI
#
# 1783.804373 ===> 324 335 SAL_NET
#
# *************************************************************************************
# **************************************text n 109**************************************
#
# MINISTERE DE LA DEFENSE naTIOnaLE ===> 0 33 ORG
#
# Juitlet 2017 ===> 90 102 DATE
#
# MEKNI IKRAM ===> 127 138 PERSON
#
# PROFESSION INTERMEDIA. ===> 154 176 EMPLOI
#
# 969.988349 ===> 332 342 SAL_NET
#
# *************************************************************************************
# **************************************text n 110**************************************
#
# MINISTERE DE L'EDUCATION naTIOnaLE ===> 0 34 ORG
#
# Juitlet 2017 ===> 91 103 DATE
#
# MORSY ZEINEB ===> 128 140 PERSON
#
# PROFESSION INTERMEDIA. ===> 156 178 EMPLOI
#
# 679.363981 ===> 334 344 SAL_NET
#
# *************************************************************************************
# **************************************text n 111**************************************
#
# MINISTERE DE L'ENSEIGNEMENT SUPERIEU ===> 0 36 ORG
#
# Juitlet 2017 ===> 93 105 DATE
#
# NAGRA MOHAMED HAITHEM ===> 130 151 PERSON
#
# PROFESSION INTERMEDIA. ===> 167 189 EMPLOI
#
# 665.392141 ===> 345 355 SAL_NET
#
# *************************************************************************************
# **************************************text n 112**************************************
#
# MINISTERE DE L'ENSEIGNEMENT SUPERIEU ===> 0 36 ORG
#
# Juitlet 2017 ===> 93 105 DATE
#
# NEFZI ISLEM ===> 130 141 PERSON
#
# PROFESSION INTERMEDIA. ===> 157 179 EMPLOI
#
# 665.392141 ===> 335 345 SAL_NET
#
# *************************************************************************************
# **************************************text n 113**************************************
#
# Juitlet 2017 ===> 93 105 DATE
#
# NEJI ELA ===> 130 138 PERSON
#
# PROFESSION INTERMEDIA. ===> 154 176 EMPLOI
#
# 1244.059181 ===> 332 343 SAL_NET
#
# *************************************************************************************
# **************************************text n 114**************************************
#
# MINISTERE DE L'ENSEIGNEMENT SUPERIEU ===> 0 36 ORG
#
# Juitlet 2017 ===> 93 105 DATE
#
# OUESLATI NOUR ===> 130 143 PERSON
#
# PROFESSION INTERMEDIA. ===> 159 181 EMPLOI
#
# 665.392141 ===> 337 347 SAL_NET
#
# *************************************************************************************
# **************************************text n 115**************************************
#
# MINISTERE DE L'ENSEIGNEMENT SUPERIEU ===> 0 36 ORG
#
# Juitlet 2017 ===> 93 105 DATE
#
# OUN MARAM ===> 130 139 PERSON
#
# PROFESSION INTERMEDIA. ===> 155 177 EMPLOI
#
# 665.392141 ===> 333 343 SAL_NET
#
# *************************************************************************************
# **************************************text n 116**************************************
#
# CHU MONGI SLIM ===> 0 14 ORG
#
# Juitlet 2017 ===> 71 83 DATE
#
# MNEJJA IMEN ===> 108 119 PERSON
#
# PROFESSION INTERMEDIA. ===> 135 157 EMPLOI
#
# 1051.257885 ===> 313 324 SAL_NET
#
# *************************************************************************************
# **************************************text n 117**************************************
#
# MINISTERE DE LA SANTE ===> 0 21 ORG
#
# Juitlet 2017 ===> 78 90 DATE
#
# REZGUI AMANI ===> 115 127 PERSON
#
# PROFESSION INTERMEDIA. ===> 143 165 EMPLOI
#
# 1002.705741 ===> 321 332 SAL_NET
#
# *************************************************************************************
# **************************************text n 118**************************************
#
# Ministere de la jeunesse et des spor ===> 0 36 ORG
#
# Juitlet 2017 ===> 93 105 DATE
#
# RIAHI SIWAR ===> 130 141 PERSON
#
# PROFESSION INTERMEDIA. ===> 157 179 EMPLOI
#
# 1263.920933 ===> 335 346 SAL_NET
#
# *************************************************************************************
# **************************************text n 119**************************************
#
# MINISTERE DE L'ENSEIGNEMENT SUPERIEU ===> 0 36 ORG
#
# Juitlet 2017 ===> 93 105 DATE
#
# RIAHI YASSMINE ===> 130 144 PERSON
#
# PROFESSION INTERMEDIA. ===> 160 182 EMPLOI
#
# 665.392141 ===> 338 348 SAL_NET
#
# *************************************************************************************
# **************************************text n 120**************************************
#
# OFFICE naTIOnaL DES POSTES ===> 0 26 ORG
#
# Juitlet 2017 ===> 83 95 DATE
#
# SIALA MHAMED ===> 120 132 PERSON
#
# PROFESSION INTERMEDIA. ===> 148 170 EMPLOI
#
# 1209.780053 ===> 326 337 SAL_NET
#
# *************************************************************************************
# **************************************text n 121**************************************
#
# CIPI ACTIA ===> 0 10 ORG
#
# Juitlet 2017 ===> 67 79 DATE
#
# SALLEMI ONS ===> 104 115 PERSON
#
# PROFESSION INTERMEDIA. ===> 131 153 EMPLOI
#
# 719.02548 ===> 309 318 SAL_NET
#
# *************************************************************************************
# **************************************text n 122**************************************
#
# COFICAB (Groupe ELLOUMI) ===> 0 24 ORG
#
# Juitlet 2017 ===> 81 93 DATE
#
# TLILI MOHAMED HEDI ===> 118 136 PERSON
#
# PROFESSION INTERMEDIA. ===> 152 174 EMPLOI
#
# 860.19079 ===> 330 339 SAL_NET
#
# *************************************************************************************
# **************************************text n 123**************************************
#
# STE STAR ===> 0 8 ORG
#
# Juitlet 2017 ===> 72 84 DATE
#
# SLIMAN EMNA ===> 109 120 PERSON
#
# PROFESSION INTERMEDIA. ===> 136 158 EMPLOI
#
# 410.73345 ===> 314 323 SAL_NET
#
# *************************************************************************************
# **************************************text n 124**************************************
#
# MINISTERE DE L'EDUCATION naTIOnaLE ===> 0 34 ORG
#
# Juitlet 2017 ===> 91 103 DATE
#
# TOUIL NESSRINE ===> 128 142 PERSON
#
# PROFESSION INTERMEDIA. ===> 158 180 EMPLOI
#
# 682.938981 ===> 336 346 SAL_NET
#
# *************************************************************************************
# **************************************text n 125**************************************
#
# UNESI ===> 0 5 ORG
#
# Juitlet 2017 ===> 62 74 DATE
#
# TOUKEBRI MELEK AMINE ===> 99 119 PERSON
#
# PROFESSION INTERMEDIA. ===> 135 157 EMPLOI
#
# 586.137965 ===> 313 323 SAL_NET
#
# *************************************************************************************
# **************************************text n 126**************************************
#
# STE STAR ===> 0 8 ORG
#
# Juitlet 2017 ===> 72 84 DATE
#
# YAKOUBI SALSABIL ===> 109 125 PERSON
#
# PROFESSION INTERMEDIA. ===> 141 163 EMPLOI
#
# 410.73345 ===> 319 328 SAL_NET
#
# *************************************************************************************
# **************************************text n 127**************************************
#
# STE STAR ===> 0 8 ORG
#
# Juitlet 2017 ===> 72 84 DATE
#
# WESLATI INES ===> 109 121 PERSON
#
# PROFESSION INTERMEDIA. ===> 137 159 EMPLOI
#
# 410.73345 ===> 315 324 SAL_NET
#
# *************************************************************************************
# **************************************text n 128**************************************
#
# SEA ===> 0 3 ORG
#
# Juitlet 2017 ===> 69 81 DATE
#
# ABBASSI CYRINE ===> 106 120 PERSON
#
# PROFESSION INTERMEDIA. ===> 136 158 EMPLOI
#
# 936.790807 ===> 314 324 SAL_NET
#
# *************************************************************************************
# **************************************text n 129**************************************
#
# OFFICE DES TERRES DOMANIALES ===> 0 28 ORG
#
# Juitlet 2017 ===> 91 103 DATE
#
# ABDELKADER MINYAR ===> 128 145 PERSON
#
# AGRICULT. EXP MOY ===> 161 178 EMPLOI
#
# 505.133589 ===> 337 347 SAL_NET
#
# *************************************************************************************
# **************************************text n 130**************************************
#
# MINISTERE DES FInaNCES ===> 0 22 ORG
#
# Juitlet 2017 ===> 79 91 DATE
#
# ABIDLI SAMAR ===> 116 128 PERSON
#
# CADRE ADMIN. SUP ===> 144 160 EMPLOI
#
# 2221.485293 ===> 316 327 SAL_NET
#
# *************************************************************************************
# **************************************text n 131**************************************
#
# OFFICE DES TERRES DOMANIALES ===> 0 28 ORG
#
# Juitlet 2017 ===> 91 103 DATE
#
# ABDESLEM ZAHER ===> 128 142 PERSON
#
# AGRICULT. EXP MOY ===> 158 175 EMPLOI
#
# 797.70612 ===> 334 343 SAL_NET
#
# *************************************************************************************
# **************************************text n 132**************************************
#
# CRIT TUNISIE ===> 0 12 ORG
#
# Juitlet 2017 ===> 69 81 DATE
#
# ALI IHEB ===> 106 114 PERSON
#
# CADRE ADMIN. SUP ===> 130 146 EMPLOI
#
# 3102.483293 ===> 302 313 SAL_NET
#
# *************************************************************************************
# **************************************text n 133**************************************
#
# UNION INTERnaTIOnaLE DE BANQUE ===> 0 30 ORG
#
# Juitlet 2017 ===> 87 99 DATE
#
# ALOUI MAHDI ===> 124 135 PERSON
#
# CADRE ADMIN. SUP ===> 151 167 EMPLOI
#
# 3327.75 ===> 323 330 SAL_NET
#
# *************************************************************************************
# **************************************text n 134**************************************
#
# CRIT TUNISIE ===> 0 12 ORG
#
# Juitlet 2017 ===> 69 81 DATE
#
# ADOUANI AHMED YASSINE ===> 106 127 PERSON
#
# CADRE ADMIN. SUP ===> 143 159 EMPLOI
#
# 3102.483293 ===> 315 326 SAL_NET
#
# *************************************************************************************
# **************************************text n 135**************************************
#
# M.INTERIEUR-SYNDIC DISTR POLICE naTI ===> 0 36 ORG
#
# Juitlet 2017 ===> 93 105 DATE
#
# AMIRI SIOUAR ===> 130 142 PERSON
#
# CADRE ADMIN. SUP ===> 158 174 EMPLOI
#
# 1539.663407 ===> 330 341 SAL_NET
#
# *************************************************************************************
# **************************************text n 136**************************************
#
# COOR SYNDICA SURETE INTERNE ET DOUAN ===> 0 36 ORG
#
# Juitlet 2017 ===> 93 105 DATE
#
# AMRI MOHAMED YASINE ===> 130 149 PERSON
#
# CADRE ADMIN. SUP ===> 165 181 EMPLOI
#
# 1687.351927 ===> 337 348 SAL_NET
#
# *************************************************************************************
# **************************************text n 137**************************************
#
# Juitlet 2017 ===> 93 105 DATE
#
# AMRI MOHAMED YASINE ===> 130 149 PERSON
#
# TECHNICIEN ===> 165 175 EMPLOI
#
# 1721.913973 ===> 331 342 SAL_NET
#
# *************************************************************************************
# **************************************text n 138**************************************
#
# Juitlet 2017 ===> 93 105 DATE
#
# ...
# **************************************text n 349**************************************
#
# MINISTERE DE L'EDUCATION naTIOnaLE ===> 0 34 ORG
#
# juillet-18 ===> 100 110 DATE
#
# 30 NOVEMBRE 2018 ===> 121 137 DATE
#
# RIAHI AMIRA ===> 181 192 PERSON
#
# EMPLOYE BUREAU ===> 208 222 EMPLOI
#
# 0.0 ===> 501 504 SAL_NET
#
# *************************************************************************************
# **************************************text n 350**************************************
#
# MINISTERE DE L'EDUCATION naTIOnaLE ===> 0 34 ORG
#
# juillet-18 ===> 100 110 DATE
#
# 30 NOVEMBRE 2018 ===> 121 137 DATE
#
# RIAHI MOHAMED ALI ===> 181 198 PERSON
#
# EMPLOYE BUREAU ===> 214 228 EMPLOI
#
# 714.054592 ===> 507 517 SAL_NET
#
# *************************************************************************************
# **************************************text n 351**************************************
#
# MINISTERE DE L'EDUCATION naTIOnaLE ===> 0 34 ORG
#
# juillet-18 ===> 100 110 DATE
#
# 30 NOVEMBRE 2018 ===> 121 137 DATE
#
# RIAHI MOHAMED KHALED ===> 181 201 PERSON
#
# EMPLOYE BUREAU ===> 217 231 EMPLOI
#
# 716.355872 ===> 510 520 SAL_NET
#
# *************************************************************************************
# **************************************text n 352**************************************
#
# MINISTERE DE L'AGRICULTURE ===> 0 26 ORG
#
# juillet-18 ===> 92 102 DATE
#
# 30 NOVEMBRE 2018 ===> 113 129 DATE
#
# RIAHI SIWAR ===> 173 184 PERSON
#
# EMPLOYE BUREAU ===> 200 214 EMPLOI
#
# 750.702476 ===> 493 503 SAL_NET
#
# *************************************************************************************
# **************************************text n 353**************************************
#
# CHU MONGI SLIM ===> 0 14 ORG
#
# juillet-18 ===> 80 90 DATE
#
# 30 NOVEMBRE 2018 ===> 101 117 DATE
#
# RIAHI YASSMINE ===> 161 175 PERSON
#
# OUVRIER ===> 191 198 EMPLOI
#
# 764.740284 ===> 477 487 SAL_NET
#
# *************************************************************************************
# **************************************text n 354**************************************
#
# HOPITAL CHARLES NICOLE DE TUNIS ===> 0 31 ORG
#
# juillet-18 ===> 97 107 DATE
#
# 30 NOVEMBRE 2018 ===> 118 134 DATE
#
# RJAIBI ALI ===> 178 188 PERSON
#
# EMPLOYE BUREAU ===> 204 218 EMPLOI
#
# 716.586 ===> 497 504 SAL_NET
#
# *************************************************************************************
# **************************************text n 355**************************************
#
# PROTECTION CIVILE ===> 0 17 ORG
#
# juillet-18 ===> 83 93 DATE
#
# 30 NOVEMBRE 2018 ===> 104 120 DATE
#
# RIAHI MOHAMED KHALIL ===> 164 184 PERSON
#
# POLICIER ===> 200 208 EMPLOI
#
# 0.0 ===> 487 490 SAL_NET
#
# *************************************************************************************
# **************************************text n 356**************************************
#
# TOUS HOPITAUX ===> 0 13 ORG
#
# juillet-18 ===> 102 112 DATE
#
# 30 NOVEMBRE 2018 ===> 123 139 DATE
#
# RZOUGA SIHEM ===> 183 195 PERSON
#
# EMPLOYE BUREAU ===> 211 225 EMPLOI
#
# 1058.153484 ===> 504 515 SAL_NET
#
# *************************************************************************************
# **************************************text n 357**************************************
#
# MUNICIPALITE DE SOUSSE ===> 0 22 ORG
#
# juillet-18 ===> 88 98 DATE
#
# 30 NOVEMBRE 2018 ===> 109 125 DATE
#
# RZOUGA SIHEM ===> 169 181 PERSON
#
# OUVRIER ===> 197 204 EMPLOI
#
# 779.353412 ===> 483 493 SAL_NET
#
# *************************************************************************************
# **************************************text n 358**************************************
#
# TOUS HOPITAUX ===> 0 13 ORG
#
# juillet-18 ===> 102 112 DATE
#
# 30 NOVEMBRE 2018 ===> 123 139 DATE
#
# RZIGA AYA ===> 183 192 PERSON
#
# EMPLOYE BUREAU ===> 208 222 EMPLOI
#
# 1058.153484 ===> 501 512 SAL_NET
#
# *************************************************************************************
# **************************************text n 359**************************************
#
# MINISTERE DE L'EDUCATION naTIOnaLE ===> 0 34 ORG
#
# juillet-18 ===> 100 110 DATE
#
# 30 NOVEMBRE 2018 ===> 121 137 DATE
#
# SAHLI RANIA ===> 181 192 PERSON
#
# PROFESSEUR ===> 208 218 EMPLOI
#
# 1166.888964 ===> 497 508 SAL_NET
#
# *************************************************************************************
# **************************************text n 360**************************************
#
# M.INTERIEUR-SYNDIC DISTR POLICE naTI ===> 0 36 ORG
#
# juillet-18 ===> 102 112 DATE
#
# 30 NOVEMBRE 2018 ===> 123 139 DATE
#
# SAIDI MOHAMED JIHED ===> 183 202 PERSON
#
# POLICIER ===> 218 226 EMPLOI
#
# 1422.9988 ===> 505 514 SAL_NET
#
# *************************************************************************************
# **************************************text n 361**************************************
#
# MINISTERE DE L'EDUCATION naTIOnaLE ===> 0 34 ORG
#
# juillet-18 ===> 100 110 DATE
#
# 30 NOVEMBRE 2018 ===> 121 137 DATE
#
# SALHI LOUA ===> 181 191 PERSON
#
# INSTITUTEUR ===> 207 218 EMPLOI
#
# 753.11882 ===> 497 506 SAL_NET
#
# *************************************************************************************
# **************************************text n 362**************************************
#
# MINISTERE DE LA DEFENSE naTIOnaLE ===> 0 33 ORG
#
# juillet-18 ===> 99 109 DATE
#
# 30 NOVEMBRE 2018 ===> 120 136 DATE
#
# SALLEMI ONS ===> 180 191 PERSON
#
# MILITAIRE ===> 207 216 EMPLOI
#
# 892.806516 ===> 495 505 SAL_NET
#
# *************************************************************************************
# **************************************text n 363**************************************
#
# MINISTERE DE L'EDUCATION naTIOnaLE ===> 0 34 ORG
#
# juillet-18 ===> 100 110 DATE
#
# 30 NOVEMBRE 2018 ===> 121 137 DATE
#
# SAFI NOUR ===> 181 190 PERSON
#
# PROFESSEUR ===> 206 216 EMPLOI
#
# 0.0 ===> 495 498 SAL_NET
#
# *************************************************************************************
# **************************************text n 364**************************************
#
# MINISTERE DES FInaNCES ===> 0 22 ORG
#
# juillet-18 ===> 88 98 DATE
#
# 30 NOVEMBRE 2018 ===> 109 125 DATE
#
# SARIATI SINDA ===> 169 182 PERSON
#
# OUVRIER ===> 198 205 EMPLOI
#
# 0.0 ===> 484 487 SAL_NET
#
# *************************************************************************************
# **************************************text n 365**************************************
#
# MINISTERE DE L'EDUCATION naTIOnaLE ===> 0 34 ORG
#
# juillet-18 ===> 100 110 DATE
#
# 30 NOVEMBRE 2018 ===> 121 137 DATE
#
# SGHAIER ZAINEB ===> 181 195 PERSON
#
# EMPLOYE BUREAU ===> 211 225 EMPLOI
#
# 776.189152 ===> 504 514 SAL_NET
#
# *************************************************************************************
# **************************************text n 366**************************************
#
# MINISTERE DES FInaNCES ===> 0 22 ORG
#
# juillet-18 ===> 88 98 DATE
#
# 30 NOVEMBRE 2018 ===> 109 125 DATE
#
# SELMI HAZEM ===> 169 180 PERSON
#
# OUVRIER ===> 196 203 EMPLOI
#
# 1336.435768 ===> 482 493 SAL_NET
#
# *************************************************************************************
# **************************************text n 367**************************************
#
# MINISTERE DE LA JEUNESSE ET DU SPORT ===> 0 36 ORG
#
# juillet-18 ===> 102 112 DATE
#
# 30 NOVEMBRE 2018 ===> 123 139 DATE
#
# SIALA MHAMED ===> 183 195 PERSON
#
# EMPLOYE DE SERVICE ===> 211 229 EMPLOI
#
# 958.2204 ===> 508 516 SAL_NET
#
# *************************************************************************************
# **************************************text n 368**************************************
#
# SMILE KIDS ===> 0 10 ORG
#
# juillet-18 ===> 76 86 DATE
#
# 30 NOVEMBRE 2018 ===> 97 113 DATE
#
# SLIMAN EMNA ===> 157 168 PERSON
#
# EMPLOYE BUREAU ===> 184 198 EMPLOI
#
# 3248.860837 ===> 477 488 SAL_NET
#
# *************************************************************************************
# **************************************text n 369**************************************
#
# BRIQUETERIE BIR MECHARGA ===> 0 24 ORG
#
# juillet-18 ===> 90 100 DATE
#
# 30 NOVEMBRE 2018 ===> 111 127 DATE
#
# SLOUMA ONS ===> 171 181 PERSON
#
# OUVRIER ===> 197 204 EMPLOI
#
# 616.786678 ===> 483 493 SAL_NET
#
# *************************************************************************************
# **************************************text n 370**************************************
#
# BRIQUETERIE BIR MECHARGA ===> 0 24 ORG
#
# juillet-18 ===> 90 100 DATE
#
# 30 NOVEMBRE 2018 ===> 111 127 DATE
#
# SLAMA CHAIMA ===> 171 183 PERSON
#
# OUVRIER ===> 199 206 EMPLOI
#
# 616.786678 ===> 485 495 SAL_NET
#
# *************************************************************************************
# **************************************text n 371**************************************
#
# BRIQUETERIE BIR MECHARGA ===> 0 24 ORG
#
# juillet-18 ===> 90 100 DATE
#
# 30 NOVEMBRE 2018 ===> 111 127 DATE
#
# TAKALI ARIJ ===> 171 182 PERSON
#
# OUVRIER ===> 198 205 EMPLOI
#
# 616.786678 ===> 484 494 SAL_NET
#
# *************************************************************************************
# **************************************text n 372**************************************
#
# UNION INTERnaTIOnaLE DE BANQUE ===> 0 30 ORG
#
# juillet-18 ===> 96 106 DATE
#
# 30 NOVEMBRE 2018 ===> 117 133 DATE
#
# THABET AMAL ===> 177 188 PERSON
#
# CADRE MOYEN ===> 204 215 EMPLOI
#
# 3233.125167 ===> 494 505 SAL_NET
#
# *************************************************************************************
# **************************************text n 373**************************************
#
# BRIQUETERIE BIR MECHARGA ===> 0 24 ORG
#
# juillet-18 ===> 90 100 DATE
#
# 30 NOVEMBRE 2018 ===> 111 127 DATE
#
# SMAALI CAMILIA ===> 171 185 PERSON
#
# OUVRIER ===> 201 208 EMPLOI
#
# 616.786678 ===> 487 497 SAL_NET
#
# *************************************************************************************
# **************************************text n 374**************************************
#
# MINISTERE DE LA DEFENSE naTIOnaLE ===> 0 33 ORG
#
# juillet-18 ===> 99 109 DATE
#
# 30 NOVEMBRE 2018 ===> 120 136 DATE
#
# THEMRI ONS ===> 180 190 PERSON
#
# MILITAIRE ===> 206 215 EMPLOI
#
# 1131.832588 ===> 494 505 SAL_NET
#
# *************************************************************************************
# **************************************text n 375**************************************
#
# SYND DG UNITES D'INTERVE ===> 0 24 ORG
#
# juillet-18 ===> 90 100 DATE
#
# 30 NOVEMBRE 2018 ===> 111 127 DATE
#
# TLIBA CHAIMA ===> 171 183 PERSON
#
# POLICIER ===> 199 207 EMPLOI
#
# 972.02808 ===> 486 495 SAL_NET
#
# *************************************************************************************
# **************************************text n 376**************************************
#
# AGROLIVA INTERnaTIOnaL ===> 0 22 ORG
#
# juillet-18 ===> 88 98 DATE
#
# 30 NOVEMBRE 2018 ===> 109 125 DATE
#
# TLILI MOHAMED HEDI ===> 169 187 PERSON
#
# OUVRIER ===> 203 210 EMPLOI
#
# 515.316799 ===> 489 499 SAL_NET
#
# *************************************************************************************
# **************************************text n 377**************************************
#
# AGROLIVA INTERnaTIOnaL ===> 0 22 ORG
#
# juillet-18 ===> 88 98 DATE
#
# 30 NOVEMBRE 2018 ===> 109 125 DATE
#
# TOUIL NESSRINE ===> 169 183 PERSON
#
# OUVRIER ===> 199 206 EMPLOI
#
# 511.941799 ===> 485 495 SAL_NET
#
# *************************************************************************************
# **************************************text n 378**************************************
#
# GOUVERNORAT DE SFAX ===> 0 19 ORG
#
# juillet-18 ===> 85 95 DATE
#
# 30 NOVEMBRE 2018 ===> 106 122 DATE
#
# TOUKEBRI MELEK AMINE ===> 166 186 PERSON
#
# EMPLOYE BUREAU ===> 202 216 EMPLOI
#
# 729.4267 ===> 495 503 SAL_NET
#
# *************************************************************************************
# **************************************text n 379**************************************
#
# ECOLE naTIOnaLE DE L'ADMINISTRATION ===> 0 35 ORG
#
# juillet-18 ===> 101 111 DATE
#
# 30 NOVEMBRE 2018 ===> 122 138 DATE
#
# TOUMIA MOHAMED AZIZ ===> 182 201 PERSON
#
# CADRE ADMIN. SUP ===> 217 233 EMPLOI
#
# 2390.641053 ===> 512 523 SAL_NET
#
# *************************************************************************************
# **************************************text n 380**************************************
#
# MINISTERE DE L'EDUCATION naTIOnaLE ===> 0 34 ORG
#
# juillet-18 ===> 100 110 DATE
#
# 30 NOVEMBRE 2018 ===> 121 137 DATE
#
# TOMBARI EYA ===> 181 192 PERSON
#
# EMPLOYE BUREAU ===> 208 222 EMPLOI
#
# 683.735228 ===> 501 511 SAL_NET
#
# *************************************************************************************
# **************************************text n 381**************************************
#
# MINISTERE DE L'EDUCATION naTIOnaLE ===> 0 34 ORG
#
# juillet-18 ===> 100 110 DATE
#
# 30 NOVEMBRE 2018 ===> 121 137 DATE
#
# TRABELSI EYA ===> 181 193 PERSON
#
# EMPLOYE BUREAU ===> 209 223 EMPLOI
#
# 787.388188 ===> 502 512 SAL_NET
#
# *************************************************************************************
# **************************************text n 382**************************************
#
# MINISTERE DE L'EDUCATION naTIOnaLE ===> 0 34 ORG
#
# juillet-18 ===> 100 110 DATE
#
# 30 NOVEMBRE 2018 ===> 121 137 DATE
#
# TURKI YASSINE ===> 181 194 PERSON
#
# EMPLOYE BUREAU ===> 210 224 EMPLOI
#
# 948.592852 ===> 503 513 SAL_NET
#
# *************************************************************************************
# **************************************text n 383**************************************
#
# MINISTERE DE LA JEUNESSE ET DU SPORT ===> 0 36 ORG
#
# juillet-18 ===> 102 112 DATE
#
# 30 NOVEMBRE 2018 ===> 123 139 DATE
#
# WESLATI INES ===> 183 195 PERSON
#
# OUVRIER ===> 211 218 EMPLOI
#
# 750.510176 ===> 497 507 SAL_NET
#
# *************************************************************************************
# **************************************text n 384**************************************
#
# MINISTERE DE L'ENSEIGNEMENT SUPERIEU ===> 0 36 ORG
#
# juillet-18 ===> 102 112 DATE
#
# 30 NOVEMBRE 2018 ===> 123 139 DATE
#
# YAKOUBI SALSABIL ===> 183 199 PERSON
#
# EMPLOYE BUREAU ===> 215 229 EMPLOI
#
# 972.095047 ===> 508 518 SAL_NET
#
# *************************************************************************************
# **************************************text n 385**************************************
#
# ECOLE naTIOnaLE DE L'ADMINISTRATION ===> 0 35 ORG
#
# juillet-18 ===> 101 111 DATE
#
# 30 NOVEMBRE 2018 ===> 122 138 DATE
#
# YAACOUBI INES ===> 182 195 PERSON
#
# CADRE ADMIN. SUP ===> 211 227 EMPLOI
#
# 2390.641053 ===> 506 517 SAL_NET
#
# *************************************************************************************
# **************************************text n 386**************************************
#
# juillet-18 ===> 83 93 DATE
#
# 30 NOVEMBRE 2018 ===> 104 120 DATE
#
# ZAGROUBA RANIA ===> 164 178 PERSON
#
# EMPLOYE BUREAU ===> 194 208 EMPLOI
#
# 837.633328 ===> 487 497 SAL_NET
#
# *************************************************************************************
# **************************************text n 387**************************************
#
# juillet-18 ===> 83 93 DATE
#
# 30 NOVEMBRE 2018 ===> 104 120 DATE
#
# ZAIEM ANIS ===> 164 174 PERSON
#
# EMPLOYE BUREAU ===> 190 204 EMPLOI
#
# 837.633328 ===> 483 493 SAL_NET
#
# *************************************************************************************
# **************************************text n 388**************************************
#
# TOUTES LES MUNICIPALITES ===> 0 24 ORG
#
# juillet-18 ===> 90 100 DATE
#
# 30 NOVEMBRE 2018 ===> 111 127 DATE
#
# ZOUZIA GHOFRANE ===> 171 186 PERSON
#
# OUVRIER ===> 202 209 EMPLOI
#
# 767.225224 ===> 488 498 SAL_NET
#
# *************************************************************************************
# **************************************text n 389**************************************
#
# MUNICIPALITE DE TATAOUINE ===> 0 25 ORG
#
# juillet-18 ===> 91 101 DATE
#
# 30 NOVEMBRE 2018 ===> 112 128 DATE
#
# ZAIDI HELA ===> 172 182 PERSON
#
# EMPLOYE BUREAU ===> 198 212 EMPLOI
#
# 780.944604 ===> 491 501 SAL_NET
#
# *************************************************************************************
# **************************************text n 390**************************************
#
# TOUTES LES MUNICIPALITES ===> 0 24 ORG
#
# juillet-18 ===> 90 100 DATE
#
# 30 NOVEMBRE 2018 ===> 111 127 DATE
#
# ZOUZIA GHOFRANE ===> 171 186 PERSON
#
# OUVRIER ===> 202 209 EMPLOI
#
# 767.225224 ===> 488 498 SAL_NET
#
# *************************************************************************************

# %%
ner = load_model("C://Users//khawl//Desktop//final work//spacy_trainedModel")
doc = ner("BULLETIN DE PAIE\nFICHE DE PAIE AVRIL 2017\nMUNICIPALITE DE GAFSA\nC.N-S.S:219541-30\nMatricule 3\nCNSS 12600357-02 1\nNom et Prénom AHMED MARWA\nQualification: EMPLOYE BUREAU\nSALAIRE DE BASE 355.000 TRANSPORT 26.112 PRIME DE PRESENCE 2.080 PRIME COMPLEMENTAIRE 355.000 SALAIRE BRUT 738.192 C.N.S.S\nSALAIRE IMPOSABLE 670.426 IMPOT SUR LE REVENUE\nSALAIRE NET 721.787333\nARRONDI PRECEDENT 0.073\nEmargement : Net a Payer : 621.500")
displacy.render(doc,jupyter=True, style = "ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">BULLETIN DE PAIE</br>FICHE DE PAIE
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AVRIL 2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MUNICIPALITE DE GAFSA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>C.N-S.S:219541-30</br>Matricule 3</br>CNSS 12600357-02 1</br>Nom et Prénom
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AHMED MARWA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Qualification:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EMPLOYE BUREAU
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EMPLOI</span>
# </mark>
# </br>SALAIRE DE BASE 355.000 TRANSPORT 26.112 PRIME DE PRESENCE 2.080 PRIME COMPLEMENTAIRE 355.000 SALAIRE BRUT 738.192 C.N.S.S</br>SALAIRE IMPOSABLE 670.426 IMPOT SUR LE REVENUE</br>SALAIRE NET
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     721.787333
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SAL_NET</span>
# </mark>
# </br>ARRONDI PRECEDENT 0.073</br>Emargement : Net a Payer : 621.500</div></span>

# %%
ner = load_model("C://Users//khawl//Desktop//final work//spacy_trainedModel")
doc = ner("MINISTERE DE L'EDUCATION naTIOnaLE\nROUTE DE TUNIS KM 6\nBULLETIN DE PAIE Affiliation enss:580033-70 juillet-18 DU ler AU 30 NOVEMBRE 2018 Matricule CNSS: 12850026-04 \nNom et Prénom TURKI YASSINE\nQualification: EMPLOYE BUREAU \nit. Fam. Code INTITULE Nbre Gains Retenues Salaire de Base 26 972.623 Prime de transport 16.112 Prime de Presence 2.080 prime complementaire provesoire 30.368, Salaire de Brut 1 021.183 Retenue de CNSS 93.975) Salaire Imposable 927.208 Impot sur le Revenu 124.300)\nSALAIRE NET 948.592852")
displacy.render(doc,jupyter=True, style = "ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MINISTERE DE L'EDUCATION naTIOnaLE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>ROUTE DE TUNIS KM 6</br>BULLETIN DE PAIE Affiliation enss:580033-70
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     juillet-18
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  DU ler AU
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     30 NOVEMBRE 2018
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  Matricule CNSS: 12850026-04 </br>Nom et Prénom
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TURKI YASSINE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Qualification:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EMPLOYE BUREAU
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EMPLOI</span>
# </mark>
#  </br>it. Fam. Code INTITULE Nbre Gains Retenues Salaire de Base 26 972.623 Prime de transport 16.112 Prime de Presence 2.080 prime complementaire provesoire 30.368, Salaire de Brut 1 021.183 Retenue de CNSS 93.975) Salaire Imposable 927.208 Impot sur le Revenu 124.300)</br>SALAIRE NET
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     948.592852
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SAL_NET</span>
# </mark>
# </div></span>

# %%
ner = load_model("C://Users//khawl//Desktop//final work//spacy_trainedModel")
doc = ner("CRIT TUNISIE\nBULLETIN DE PAIE\nMatricule i; NÂ° CNSS 16390112-02\nMois Juitlet 2017 Sit Fame;\nNom et Prénom ADOUANI AHMED YASSINE\nQualification: CADRE ADMIN. SUP\nLibelle Nombre Sal/Prime Retenues \nSALAIRE DE BASE 18 642 \nPRIME DE PRESENCE 260 11.568\nPRIME DE TRANSPORT 260 57.183\nIMPOT SUR SALAIRE 90.198\nSALAIRE NET 3102.483293\nSALAIRE A PAYER 758.154\nEmargement\nNET A PAYER 798.154")
displacy.render(doc,jupyter=True, style = "ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CRIT TUNISIE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>BULLETIN DE PAIE</br>Matricule i; NÂ° CNSS 16390112-02</br>Mois
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Juitlet 2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  Sit Fame;</br>Nom et Prénom
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ADOUANI AHMED YASSINE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Qualification:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CADRE ADMIN. SUP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EMPLOI</span>
# </mark>
# </br>Libelle Nombre Sal/Prime Retenues </br>SALAIRE DE BASE 18 642 </br>PRIME DE PRESENCE 260 11.568</br>PRIME DE TRANSPORT 260 57.183</br>IMPOT SUR SALAIRE 90.198</br>SALAIRE NET
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3102.483293
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SAL_NET</span>
# </mark>
# </br>SALAIRE A PAYER 758.154</br>Emargement</br>NET A PAYER 798.154</div></span>

# %%
test_sentences = [x[0] for x in TEST_DATA] # extract the sentences from [sentence, entity]
i=0
for x in test_sentences:
    i=i+1
    doc = ner(x)
    print("**************************************text n "+ str(i)+"**************************************\n")
    displacy.render(doc,jupyter=True, style = "ent")
    print("*************************************************************************************")
# Out:
# **************************************text n 1**************************************
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">BULLETIN DE PAIE</br>FICHE DE PAIE
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AVRIL 2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MINISTERE DE L'EDUCATION naTIOnaLE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>C.N-S.S:219541-30</br>Matricule 3</br>CNSS 12600357-02 1</br>Nom et Prénom
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NAOUEL BOCHRA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Qualification:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PROFESSEUR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EMPLOI</span>
# </mark>
# </br>SALAIRE DE BASE 355.000 TRANSPORT 26.112 PRIME DE PRESENCE 2.080 PRIME COMPLEMENTAIRE 355.000 SALAIRE BRUT 738.192 C.N.S.S</br>SALAIRE IMPOSABLE 670.426 IMPOT SUR LE REVENUE</br>SALAIRE NET
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1161.314853
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SAL_NET</span>
# </mark>
# </br>ARRONDI PRECEDENT 0.073</br>Emargement : Net a Payer : 621.500</div></span>
# *************************************************************************************
# **************************************text n 2**************************************
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">BULLETIN DE PAIE</br>FICHE DE PAIE
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AVRIL 2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MINISTERE DE L'EDUCATION naTIOnaLE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>C.N-S.S:219541-30</br>Matricule 3</br>CNSS 12600357-02 1</br>Nom et Prénom
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NAMOUCHI FIRAS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Qualification:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PROFESSEUR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EMPLOI</span>
# </mark>
# </br>SALAIRE DE BASE 355.000 TRANSPORT 26.112 PRIME DE PRESENCE 2.080 PRIME COMPLEMENTAIRE 355.000 SALAIRE BRUT 738.192 C.N.S.S</br>SALAIRE IMPOSABLE 670.426 IMPOT SUR LE REVENUE</br>SALAIRE NET
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1503.113867
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SAL_NET</span>
# </mark>
# </br>ARRONDI PRECEDENT 0.073</br>Emargement : Net a Payer : 621.500</div></span>
# *************************************************************************************
# **************************************text n 3**************************************
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">BULLETIN DE PAIE</br>FICHE DE PAIE
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AVRIL 2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MINISTERE DE LA DEFENSE naTIOnaLE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>C.N-S.S:219541-30</br>Matricule 3</br>CNSS 12600357-02 1</br>Nom et Prénom
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NASRI AICHA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Qualification:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MILITAIRE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EMPLOI</span>
# </mark>
# </br>SALAIRE DE BASE 355.000 TRANSPORT 26.112 PRIME DE PRESENCE 2.080 PRIME COMPLEMENTAIRE 355.000 SALAIRE BRUT 738.192 C.N.S.S</br>SALAIRE IMPOSABLE 670.426 IMPOT SUR LE REVENUE</br>SALAIRE NET
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     788.556133
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SAL_NET</span>
# </mark>
# </br>ARRONDI PRECEDENT 0.073</br>Emargement : Net a Payer : 621.500</div></span>
# *************************************************************************************
# **************************************text n 4**************************************
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">BULLETIN DE PAIE</br>FICHE DE PAIE
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AVRIL 2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MINISTERE DE LA DEFENSE naTIOnaLE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>C.N-S.S:219541-30</br>Matricule 3</br>CNSS 12600357-02 1</br>Nom et Prénom
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NEJI MALEK
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Qualification:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MILITAIRE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EMPLOI</span>
# </mark>
# </br>SALAIRE DE BASE 355.000 TRANSPORT 26.112 PRIME DE PRESENCE 2.080 PRIME COMPLEMENTAIRE 355.000 SALAIRE BRUT 738.192 C.N.S.S</br>SALAIRE IMPOSABLE 670.426 IMPOT SUR LE REVENUE</br>SALAIRE NET
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     803.740933
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SAL_NET</span>
# </mark>
# </br>ARRONDI PRECEDENT 0.073</br>Emargement : Net a Payer : 621.500</div></span>
# *************************************************************************************
# **************************************text n 5**************************************
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">BULLETIN DE PAIE</br>FICHE DE PAIE
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AVRIL 2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MINISTERE DE LA DEFENSE naTIOnaLE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>C.N-S.S:219541-30</br>Matricule 3</br>CNSS 12600357-02 1</br>Nom et Prénom
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     OMRI GHADA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Qualification:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MILITAIRE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EMPLOI</span>
# </mark>
# </br>SALAIRE DE BASE 355.000 TRANSPORT 26.112 PRIME DE PRESENCE 2.080 PRIME COMPLEMENTAIRE 355.000 SALAIRE BRUT 738.192 C.N.S.S</br>SALAIRE IMPOSABLE 670.426 IMPOT SUR LE REVENUE</br>SALAIRE NET
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     800.366533
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SAL_NET</span>
# </mark>
# </br>ARRONDI PRECEDENT 0.073</br>Emargement : Net a Payer : 621.500</div></span>
# *************************************************************************************
# **************************************text n 6**************************************
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">BULLETIN DE PAIE</br>FICHE DE PAIE
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AVRIL 2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MINISTERE DE LA DEFENSE naTIOnaLE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>C.N-S.S:219541-30</br>Matricule 3</br>CNSS 12600357-02 1</br>Nom et Prénom
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     OBAYNA LINDA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Qualification:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MILITAIRE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EMPLOI</span>
# </mark>
# </br>SALAIRE DE BASE 355.000 TRANSPORT 26.112 PRIME DE PRESENCE 2.080 PRIME COMPLEMENTAIRE 355.000 SALAIRE BRUT 738.192 C.N.S.S</br>SALAIRE IMPOSABLE 670.426 IMPOT SUR LE REVENUE</br>SALAIRE NET
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     803.740933
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SAL_NET</span>
# </mark>
# </br>ARRONDI PRECEDENT 0.073</br>Emargement : Net a Payer : 621.500</div></span>
# *************************************************************************************
# **************************************text n 7**************************************
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">BULLETIN DE PAIE</br>FICHE DE PAIE
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AVRIL 2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MINISTERE DE L'EDUCATION naTIOnaLE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>C.N-S.S:219541-30</br>Matricule 3</br>CNSS 12600357-02 1</br>Nom et Prénom
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     OUADA MOHAMED MOEMEN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Qualification:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     INSTITUTEUR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EMPLOI</span>
# </mark>
# </br>SALAIRE DE BASE 355.000 TRANSPORT 26.112 PRIME DE PRESENCE 2.080 PRIME COMPLEMENTAIRE 355.000 SALAIRE BRUT 738.192 C.N.S.S</br>SALAIRE IMPOSABLE 670.426 IMPOT SUR LE REVENUE</br>SALAIRE NET
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1270.633493
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SAL_NET</span>
# </mark>
# </br>ARRONDI PRECEDENT 0.073</br>Emargement : Net a Payer : 621.500</div></span>
# *************************************************************************************
# **************************************text n 8**************************************
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">BULLETIN DE PAIE</br>FICHE DE PAIE
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AVRIL 2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MINISTERE DE LA DEFENSE naTIOnaLE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>C.N-S.S:219541-30</br>Matricule 3</br>CNSS 12600357-02 1</br>Nom et Prénom
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     OUALLANI ESSIA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Qualification:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MILITAIRE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EMPLOI</span>
# </mark>
# </br>SALAIRE DE BASE 355.000 TRANSPORT 26.112 PRIME DE PRESENCE 2.080 PRIME COMPLEMENTAIRE 355.000 SALAIRE BRUT 738.192 C.N.S.S</br>SALAIRE IMPOSABLE 670.426 IMPOT SUR LE REVENUE</br>SALAIRE NET
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     949.065093
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SAL_NET</span>
# </mark>
# </br>ARRONDI PRECEDENT 0.073</br>Emargement : Net a Payer : 621.500</div></span>
# *************************************************************************************
# **************************************text n 9**************************************
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">BULLETIN DE PAIE</br>FICHE DE PAIE
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AVRIL 2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MINISTERE DE LA DEFENSE naTIOnaLE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>C.N-S.S:219541-30</br>Matricule 3</br>CNSS 12600357-02 1</br>Nom et Prénom
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     OUARGHI NADA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Qualification:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MILITAIRE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EMPLOI</span>
# </mark>
# </br>SALAIRE DE BASE 355.000 TRANSPORT 26.112 PRIME DE PRESENCE 2.080 PRIME COMPLEMENTAIRE 355.000 SALAIRE BRUT 738.192 C.N.S.S</br>SALAIRE IMPOSABLE 670.426 IMPOT SUR LE REVENUE</br>SALAIRE NET
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     793.167813
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SAL_NET</span>
# </mark>
# </br>ARRONDI PRECEDENT 0.073</br>Emargement : Net a Payer : 621.500</div></span>
# *************************************************************************************
# **************************************text n 10**************************************
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">BULLETIN DE PAIE</br>FICHE DE PAIE
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AVRIL 2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MINISTERE DE LA DEFENSE naTIOnaLE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>C.N-S.S:219541-30</br>Matricule 3</br>CNSS 12600357-02 1</br>Nom et Prénom
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     OUERTANI SARRA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Qualification:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MILITAIRE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EMPLOI</span>
# </mark>
# </br>SALAIRE DE BASE 355.000 TRANSPORT 26.112 PRIME DE PRESENCE 2.080 PRIME COMPLEMENTAIRE 355.000 SALAIRE BRUT 738.192 C.N.S.S</br>SALAIRE IMPOSABLE 670.426 IMPOT SUR LE REVENUE</br>SALAIRE NET
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     793.167813
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SAL_NET</span>
# </mark>
# </br>ARRONDI PRECEDENT 0.073</br>Emargement : Net a Payer : 621.500</div></span>
# *************************************************************************************
# **************************************text n 11**************************************
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">BULLETIN DE PAIE</br>FICHE DE PAIE
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AVRIL 2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MINISTERE DE L'EDUCATION naTIOnaLE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>C.N-S.S:219541-30</br>Matricule 3</br>CNSS 12600357-02 1</br>Nom et Prénom
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     RAHMANI EMNA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Qualification:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PROFESSEUR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EMPLOI</span>
# </mark>
# </br>SALAIRE DE BASE 355.000 TRANSPORT 26.112 PRIME DE PRESENCE 2.080 PRIME COMPLEMENTAIRE 355.000 SALAIRE BRUT 738.192 C.N.S.S</br>SALAIRE IMPOSABLE 670.426 IMPOT SUR LE REVENUE</br>SALAIRE NET
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1287.348693
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SAL_NET</span>
# </mark>
# </br>ARRONDI PRECEDENT 0.073</br>Emargement : Net a Payer : 621.500</div></span>
# *************************************************************************************
# **************************************text n 12**************************************
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">BULLETIN DE PAIE</br>FICHE DE PAIE
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AVRIL 2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MINISTERE DE LA DEFENSE naTIOnaLE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>C.N-S.S:219541-30</br>Matricule 3</br>CNSS 12600357-02 1</br>Nom et Prénom
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     OUESLATI MAHDI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Qualification:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MILITAIRE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EMPLOI</span>
# </mark>
# </br>SALAIRE DE BASE 355.000 TRANSPORT 26.112 PRIME DE PRESENCE 2.080 PRIME COMPLEMENTAIRE 355.000 SALAIRE BRUT 738.192 C.N.S.S</br>SALAIRE IMPOSABLE 670.426 IMPOT SUR LE REVENUE</br>SALAIRE NET
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     951.143964
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SAL_NET</span>
# </mark>
# </br>ARRONDI PRECEDENT 0.073</br>Emargement : Net a Payer : 621.500</div></span>
# *************************************************************************************
# **************************************text n 13**************************************
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">BULLETIN DE PAIE</br>FICHE DE PAIE
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AVRIL 2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MINISTERE DE L'EDUCATION naTIOnaLE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>C.N-S.S:219541-30</br>Matricule 3</br>CNSS 12600357-02 1</br>Nom et Prénom
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     RHOUMA NADA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Qualification:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PROFESSEUR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EMPLOI</span>
# </mark>
# </br>SALAIRE DE BASE 355.000 TRANSPORT 26.112 PRIME DE PRESENCE 2.080 PRIME COMPLEMENTAIRE 355.000 SALAIRE BRUT 738.192 C.N.S.S</br>SALAIRE IMPOSABLE 670.426 IMPOT SUR LE REVENUE</br>SALAIRE NET
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1287.348693
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SAL_NET</span>
# </mark>
# </br>ARRONDI PRECEDENT 0.073</br>Emargement : Net a Payer : 621.500</div></span>
# *************************************************************************************
# **************************************text n 14**************************************
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">BULLETIN DE PAIE</br>FICHE DE PAIE
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AVRIL 2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MINISTERE DE L'EDUCATION naTIOnaLE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>C.N-S.S:219541-30</br>Matricule 3</br>CNSS 12600357-02 1</br>Nom et Prénom
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     REZGUI AMINE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Qualification:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PROFESSEUR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EMPLOI</span>
# </mark>
# </br>SALAIRE DE BASE 355.000 TRANSPORT 26.112 PRIME DE PRESENCE 2.080 PRIME COMPLEMENTAIRE 355.000 SALAIRE BRUT 738.192 C.N.S.S</br>SALAIRE IMPOSABLE 670.426 IMPOT SUR LE REVENUE</br>SALAIRE NET
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1287.348693
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SAL_NET</span>
# </mark>
# </br>ARRONDI PRECEDENT 0.073</br>Emargement : Net a Payer : 621.500</div></span>
# *************************************************************************************
# **************************************text n 15**************************************
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">BULLETIN DE PAIE</br>FICHE DE PAIE
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AVRIL 2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MINISTERE DE L'EDUCATION naTIOnaLE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>C.N-S.S:219541-30</br>Matricule 3</br>CNSS 12600357-02 1</br>Nom et Prénom
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     RIAHI AMIRA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Qualification:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PROFESSEUR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EMPLOI</span>
# </mark>
# </br>SALAIRE DE BASE 355.000 TRANSPORT 26.112 PRIME DE PRESENCE 2.080 PRIME COMPLEMENTAIRE 355.000 SALAIRE BRUT 738.192 C.N.S.S</br>SALAIRE IMPOSABLE 670.426 IMPOT SUR LE REVENUE</br>SALAIRE NET
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1287.348693
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SAL_NET</span>
# </mark>
# </br>ARRONDI PRECEDENT 0.073</br>Emargement : Net a Payer : 621.500</div></span>
# *************************************************************************************
# **************************************text n 16**************************************
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">BULLETIN DE PAIE</br>FICHE DE PAIE
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AVRIL 2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MINISTERE DE L'EDUCATION naTIOnaLE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>C.N-S.S:219541-30</br>Matricule 3</br>CNSS 12600357-02 1</br>Nom et Prénom
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     RIAHI MOHAMED ALI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Qualification:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PROFESSEUR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EMPLOI</span>
# </mark>
# </br>SALAIRE DE BASE 355.000 TRANSPORT 26.112 PRIME DE PRESENCE 2.080 PRIME COMPLEMENTAIRE 355.000 SALAIRE BRUT 738.192 C.N.S.S</br>SALAIRE IMPOSABLE 670.426 IMPOT SUR LE REVENUE</br>SALAIRE NET
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1515.676373
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SAL_NET</span>
# </mark>
# </br>ARRONDI PRECEDENT 0.073</br>Emargement : Net a Payer : 621.500</div></span>
# *************************************************************************************
# **************************************text n 17**************************************
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">BULLETIN DE PAIE</br>FICHE DE PAIE
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AVRIL 2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MINISTERE DE LA DEFENSE naTIOnaLE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>C.N-S.S:219541-30</br>Matricule 3</br>CNSS 12600357-02 1</br>Nom et Prénom
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     RIAHI MOHAMED KHALIL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Qualification:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MILITAIRE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EMPLOI</span>
# </mark>
# </br>SALAIRE DE BASE 355.000 TRANSPORT 26.112 PRIME DE PRESENCE 2.080 PRIME COMPLEMENTAIRE 355.000 SALAIRE BRUT 738.192 C.N.S.S</br>SALAIRE IMPOSABLE 670.426 IMPOT SUR LE REVENUE</br>SALAIRE NET
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     814.089093
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SAL_NET</span>
# </mark>
# </br>ARRONDI PRECEDENT 0.073</br>Emargement : Net a Payer : 621.500</div></span>
# *************************************************************************************
# **************************************text n 18**************************************
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">BULLETIN DE PAIE</br>FICHE DE PAIE
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AVRIL 2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MINISTERE DE L'EDUCATION naTIOnaLE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>C.N-S.S:219541-30</br>Matricule 3</br>CNSS 12600357-02 1</br>Nom et Prénom
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     RIAHI MOHAMED KHALED
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Qualification:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PROFESSEUR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EMPLOI</span>
# </mark>
# </br>SALAIRE DE BASE 355.000 TRANSPORT 26.112 PRIME DE PRESENCE 2.080 PRIME COMPLEMENTAIRE 355.000 SALAIRE BRUT 738.192 C.N.S.S</br>SALAIRE IMPOSABLE 670.426 IMPOT SUR LE REVENUE</br>SALAIRE NET
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1600.982773
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SAL_NET</span>
# </mark>
# </br>ARRONDI PRECEDENT 0.073</br>Emargement : Net a Payer : 621.500</div></span>
# *************************************************************************************
# **************************************text n 19**************************************
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">BULLETIN DE PAIE</br>FICHE DE PAIE
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AVRIL 2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MINISTERE DE LA DEFENSE naTIOnaLE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>C.N-S.S:219541-30</br>Matricule 3</br>CNSS 12600357-02 1</br>Nom et Prénom
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     RJAIBI ALI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Qualification:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MILITAIRE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EMPLOI</span>
# </mark>
# </br>SALAIRE DE BASE 355.000 TRANSPORT 26.112 PRIME DE PRESENCE 2.080 PRIME COMPLEMENTAIRE 355.000 SALAIRE BRUT 738.192 C.N.S.S</br>SALAIRE IMPOSABLE 670.426 IMPOT SUR LE REVENUE</br>SALAIRE NET
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     814.089093
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SAL_NET</span>
# </mark>
# </br>ARRONDI PRECEDENT 0.073</br>Emargement : Net a Payer : 621.500</div></span>
# *************************************************************************************
# **************************************text n 20**************************************
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">BULLETIN DE PAIE</br>FICHE DE PAIE
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AVRIL 2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MINISTERE DE L'EDUCATION naTIOnaLE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>C.N-S.S:219541-30</br>Matricule 3</br>CNSS 12600357-02 1</br>Nom et Prénom
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SAAFI WASSIM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Qualification:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PROFESSEUR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EMPLOI</span>
# </mark>
# </br>SALAIRE DE BASE 355.000 TRANSPORT 26.112 PRIME DE PRESENCE 2.080 PRIME COMPLEMENTAIRE 355.000 SALAIRE BRUT 738.192 C.N.S.S</br>SALAIRE IMPOSABLE 670.426 IMPOT SUR LE REVENUE</br>SALAIRE NET
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1101.081813
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SAL_NET</span>
# </mark>
# </br>ARRONDI PRECEDENT 0.073</br>Emargement : Net a Payer : 621.500</div></span>
# *************************************************************************************
# **************************************text n 21**************************************
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">BULLETIN DE PAIE</br>FICHE DE PAIE
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AVRIL 2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# ...
# </mark>
# </br></div></span>
# *************************************************************************************
# **************************************text n 385**************************************
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ECOLE naTIOnaLE DE L'ADMINISTRATION
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>ROUTE DE TUNIS KM 6 </br>BULLETIN DE PAIE Affiliation enss:580033-70
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     juillet-18
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  DU ler AU
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     30 NOVEMBRE 2018
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  Matricule CNSS: 12850026-04 </br>Nom et Prénom
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     YAACOUBI INES
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Qualification:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CADRE ADMIN. SUP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EMPLOI</span>
# </mark>
# </br>it. Fam. Code INTITULE Nbre Gains Retenues Salaire de Base 26 972.623 Prime de transport 16.112 Prime de Presence 2.080 prime complementaire provesoire 30.368, Salaire de Brut 1 021.183 Retenue de CNSS 93.975) Salaire Imposable 927.208 Impot sur le Revenu 124.300) </br>SALAIRE NET
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2390.641053
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SAL_NET</span>
# </mark>
# </br></div></span>
# *************************************************************************************
# **************************************text n 386**************************************
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">AMICALE DE LA BCT</br>ROUTE DE TUNIS KM 6 </br>BULLETIN DE PAIE Affiliation enss:580033-70
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     juillet-18
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  DU ler AU
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     30 NOVEMBRE 2018
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  Matricule CNSS: 12850026-04 </br>Nom et Prénom
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ZAGROUBA RANIA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Qualification:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EMPLOYE BUREAU
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EMPLOI</span>
# </mark>
# </br>it. Fam. Code INTITULE Nbre Gains Retenues Salaire de Base 26 972.623 Prime de transport 16.112 Prime de Presence 2.080 prime complementaire provesoire 30.368, Salaire de Brut 1 021.183 Retenue de CNSS 93.975) Salaire Imposable 927.208 Impot sur le Revenu 124.300) </br>SALAIRE NET
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     837.633328
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SAL_NET</span>
# </mark>
# </br></div></span>
# *************************************************************************************
# **************************************text n 387**************************************
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">AMICALE DE LA BCT</br>ROUTE DE TUNIS KM 6 </br>BULLETIN DE PAIE Affiliation enss:580033-70
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     juillet-18
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  DU ler AU
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     30 NOVEMBRE 2018
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  Matricule CNSS: 12850026-04 </br>Nom et Prénom
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ZAIEM ANIS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Qualification:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EMPLOYE BUREAU
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EMPLOI</span>
# </mark>
# </br>it. Fam. Code INTITULE Nbre Gains Retenues Salaire de Base 26 972.623 Prime de transport 16.112 Prime de Presence 2.080 prime complementaire provesoire 30.368, Salaire de Brut 1 021.183 Retenue de CNSS 93.975) Salaire Imposable 927.208 Impot sur le Revenu 124.300) </br>SALAIRE NET
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     837.633328
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SAL_NET</span>
# </mark>
# </br></div></span>
# *************************************************************************************
# **************************************text n 388**************************************
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TOUTES LES MUNICIPALITES
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>ROUTE DE TUNIS KM 6 </br>BULLETIN DE PAIE Affiliation enss:580033-70
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     juillet-18
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  DU ler AU
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     30 NOVEMBRE 2018
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  Matricule CNSS: 12850026-04 </br>Nom et Prénom
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ZOUZIA GHOFRANE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Qualification:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     OUVRIER
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EMPLOI</span>
# </mark>
# </br>it. Fam. Code INTITULE Nbre Gains Retenues Salaire de Base 26 972.623 Prime de transport 16.112 Prime de Presence 2.080 prime complementaire provesoire 30.368, Salaire de Brut 1 021.183 Retenue de CNSS 93.975) Salaire Imposable 927.208 Impot sur le Revenu 124.300) </br>SALAIRE NET
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     767.225224
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SAL_NET</span>
# </mark>
# </br></div></span>
# *************************************************************************************
# **************************************text n 389**************************************
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MUNICIPALITE DE TATAOUINE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>ROUTE DE TUNIS KM 6 </br>BULLETIN DE PAIE Affiliation enss:580033-70
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     juillet-18
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  DU ler AU
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     30 NOVEMBRE 2018
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  Matricule CNSS: 12850026-04 </br>Nom et Prénom
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ZAIDI HELA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Qualification:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EMPLOYE BUREAU
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EMPLOI</span>
# </mark>
# </br>it. Fam. Code INTITULE Nbre Gains Retenues Salaire de Base 26 972.623 Prime de transport 16.112 Prime de Presence 2.080 prime complementaire provesoire 30.368, Salaire de Brut 1 021.183 Retenue de CNSS 93.975) Salaire Imposable 927.208 Impot sur le Revenu 124.300) </br>SALAIRE NET
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     780.944604
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SAL_NET</span>
# </mark>
# </br></div></span>
# *************************************************************************************
# **************************************text n 390**************************************
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TOUTES LES MUNICIPALITES
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>ROUTE DE TUNIS KM 6 </br>BULLETIN DE PAIE Affiliation enss:580033-70
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     juillet-18
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  DU ler AU
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     30 NOVEMBRE 2018
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  Matricule CNSS: 12850026-04 </br>Nom et Prénom
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ZOUZIA GHOFRANE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Qualification:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     OUVRIER
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EMPLOI</span>
# </mark>
# </br>it. Fam. Code INTITULE Nbre Gains Retenues Salaire de Base 26 972.623 Prime de transport 16.112 Prime de Presence 2.080 prime complementaire provesoire 30.368, Salaire de Brut 1 021.183 Retenue de CNSS 93.975) Salaire Imposable 927.208 Impot sur le Revenu 124.300) </br>SALAIRE NET
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     767.225224
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SAL_NET</span>
# </mark>
# </br></div></span>
# *************************************************************************************
